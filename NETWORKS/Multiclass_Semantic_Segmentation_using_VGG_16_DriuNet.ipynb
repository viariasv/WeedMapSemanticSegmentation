# %% [markdown]
# # Multiclass Semantic Segmentation using WeedMap dataset

# %% [markdown]
# ## Introduction
# - Semantic Segmentation of an image is to assign each pixel in the input image a semantic class in order to get a pixel-wise dense classification.
# - A general semantic segmentation architecture can be broadly thought of as an encoder network followed by a decoder network. - - The encoder is usually is a pre-trained classification network like VGG/ResNet followed by a decoder network. The decoder network/mechanism is mostly where these architectures differ.
# - The task of the decoder is to semantically project the discriminative features (lower resolution) learnt by the encoder onto the pixel space (higher resolution) to get a dense classification. (mechanisms like skip connections, pyramid pooling etc are used for this)

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import random
import re
import cv2
from PIL import Image
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score, accuracy_score

import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import os
import sys
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import *


#from tensorflow.keras.engine import Layer
from tensorflow.keras.applications.vgg16 import *
from tensorflow.keras.models import *
#from tensorflow.keras.applications.imagenet_utils import _obtain_input_shape
import tensorflow.keras.backend as K
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Convolution2D, ZeroPadding2D, MaxPooling2D, Cropping2D, Conv2D
from tensorflow.keras.layers import Input, Add, Dropout, Permute, add
from tensorflow.compat.v1.layers import conv2d_transpose
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# # Environment checks

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
x = tf.random.uniform([3, 3])

print("Is there a GPU available: "),
print(tf.test.is_gpu_available())

print("Is the Tensor on GPU #0:  "),
print(x.device.endswith('GPU:0'))

print("Device name: {}".format((x.device)))
# Out:
# Is there a GPU available:
# True
# Is the Tensor on GPU #0:
# True
# Device name: /job:localhost/replica:0/task:0/device:GPU:0

# %%
print(tf.executing_eagerly())
# Out:
# True

# %%
#!wget http://mi.eng.cam.ac.uk/research/projects/VideoRec/CamSeq01/CamSeq01.zip

# %%
cwd = os.getcwd()
cwd
# Out:
# '/home/lisi2020/Downloads/Multiclass-Semantic-Segmentation-CamVid-master'

# %%
#!mkdir data
#!mkdir data/CamSeq01

# %%
#!unzip CamSeq01.zip -d data/CamSeq01

# %% [markdown]
# ## Data preparation - Importing, Cleaning and Creating structured directory

# %% [markdown]
# ### Function to import and process frames and masks as tensors

# %%
def _read_to_tensor(fname, output_height=224, output_width=224, normalize_data=False):
    '''Function to read images from given image file path, and provide resized images as tensors
        Inputs: 
            fname - image file path
            output_height - required output image height
            output_width - required output image width
            normalize_data - if True, normalize data to be centered around 0 (mean 0, range 0 to 1)
        Output: Processed image tensors
    '''
    
    # Read the image as a tensor
    img_strings = tf.io.read_file(fname)
    imgs_decoded = tf.image.decode_jpeg(img_strings)

    # Resize the image
    output = tf.image.resize(imgs_decoded, [output_height, output_width])
    # Normalize if required
    if normalize_data:
        output = (output - 128) / 128
    return output

# %% [markdown]
# ### Image directory and size parameters

# %%
import shutil

## Try to remove tree; if failed show an error using try...except on screen
#shutil.rmtree("data/CamSeq01/train_frames")
#shutil.rmtree("data/CamSeq01/train_masks")
#shutil.rmtree("data/CamSeq01/val_frames")
#shutil.rmtree("data/CamSeq01/val_masks")

img_dir = '/home/lisi2020/Downloads/Multiclass-Semantic-Segmentation-CamVid-master/RedEdge/'

# Required image dimensions
output_height = 224
output_width = 224

# %% [markdown]
# ### Reading frames and masks
# - Mask file names end in "\_L.png"

# %%
file_list = os.listdir(img_dir)
file_list
# Out:
# ['val_masks',
#  'test_masks',
#  'train',
#  'test',
#  'val_frames',
#  'label_colors.txt',
#  'train_frames',
#  'test_frames',
#  'train_masks']

# %%
def read_images(img_dir):
    '''Function to get all image directories, read images and masks in separate tensors
        Inputs: 
            img_dir - file directory
        Outputs 
            frame_tensors, masks_tensors, frame files list, mask files list
    '''
    
    # Get the file names list from provided directory
    file_list = [f for f in os.listdir(img_dir) if os.path.isfile(os.path.join(img_dir, f))]
    
    # Separate frame and mask files lists, exclude unnecessary files
    frames_list = [file for file in file_list if ('_L' not in file) and ('txt' not in file)]
    masks_list = [file for file in file_list if ('_L' in file) and ('txt' not in file)]
    
    frames_list = sorted(frames_list)
    masks_list = sorted(masks_list)
    
    print('{} frame files found in the provided directory.'.format(len(frames_list)))
    print('{} mask files found in the provided directory.'.format(len(masks_list)))
    
    # Create file paths from file names
    frames_paths = [os.path.join(img_dir, fname) for fname in frames_list]
    masks_paths = [os.path.join(img_dir, fname) for fname in masks_list]
    
    # Create dataset of tensors
    frame_data = tf.data.Dataset.from_tensor_slices(frames_paths)
    masks_data = tf.data.Dataset.from_tensor_slices(masks_paths)
    
    # Read images into the tensor dataset
    frame_tensors = frame_data.map(_read_to_tensor)
    masks_tensors = masks_data.map(_read_to_tensor)
    
    print('Completed importing {} frame images from the provided directory.'.format(len(frames_list)))
    print('Completed importing {} mask images from the provided directory.'.format(len(masks_list)))
    
    return frame_tensors, masks_tensors, frames_list, masks_list

train_frame_tensors, train_masks_tensors, train_frames_list, train_masks_list = read_images(os.path.join(img_dir, "train"))
test_frame_tensors, test_masks_tensors, test_frames_list, test_masks_list = read_images(os.path.join(img_dir, "test"))
# Out:
# 766 frame files found in the provided directory.
# 766 mask files found in the provided directory.
# Completed importing 766 frame images from the provided directory.
# Completed importing 766 mask images from the provided directory.
# 204 frame files found in the provided directory.
# 204 mask files found in the provided directory.
# Completed importing 204 frame images from the provided directory.
# Completed importing 204 mask images from the provided directory.

# %%
#masks_list.sort()
#print(len(masks_list))
train_frames_list
# Out:
# ['frame0000.png',
#  'frame0001.png',
#  'frame0002.png',
#  'frame0003.png',
#  'frame0004.png',
#  'frame0005.png',
#  'frame0006.png',
#  'frame0007.png',
#  'frame0008.png',
#  'frame0009.png',
#  'frame0010.png',
#  'frame0011.png',
#  'frame0012.png',
#  'frame0013.png',
#  'frame0014.png',
#  'frame0015.png',
#  'frame0016.png',
#  'frame0017.png',
#  'frame0018.png',
#  'frame0019.png',
#  'frame0020.png',
#  'frame0021.png',
#  'frame0022.png',
#  'frame0023.png',
#  'frame0024.png',
#  'frame0025.png',
#  'frame0026.png',
#  'frame0027.png',
#  'frame0028.png',
#  'frame0029.png',
#  'frame0030.png',
#  'frame0031.png',
#  'frame0032.png',
#  'frame0033.png',
#  'frame0034.png',
#  'frame0035.png',
#  'frame0036.png',
#  'frame0037.png',
#  'frame0038.png',
#  'frame0039.png',
#  'frame0040.png',
#  'frame0041.png',
#  'frame0042.png',
#  'frame0043.png',
#  'frame0044.png',
#  'frame0045.png',
#  'frame0046.png',
#  'frame0047.png',
#  'frame0048.png',
#  'frame0049.png',
#  'frame0050.png',
#  'frame0051.png',
#  'frame0052.png',
#  'frame0053.png',
#  'frame0054.png',
#  'frame0055.png',
#  'frame0056.png',
#  'frame0057.png',
#  'frame0058.png',
#  'frame0059.png',
#  'frame0060.png',
#  'frame0061.png',
#  'frame0062.png',
#  'frame0063.png',
#  'frame0064.png',
#  'frame0065.png',
#  'frame0066.png',
#  'frame0067.png',
#  'frame0068.png',
#  'frame0069.png',
#  'frame0070.png',
#  'frame0071.png',
#  'frame0072.png',
#  'frame0073.png',
#  'frame0074.png',
#  'frame0075.png',
#  'frame0076.png',
#  'frame0077.png',
#  'frame0078.png',
#  'frame0079.png',
#  'frame0080.png',
#  'frame0081.png',
#  'frame0082.png',
#  'frame0083.png',
#  'frame0084.png',
#  'frame0085.png',
#  'frame0086.png',
#  'frame0087.png',
#  'frame0088.png',
#  'frame0089.png',
#  'frame0090.png',
#  'frame0091.png',
#  'frame0092.png',
#  'frame0093.png',
#  'frame0094.png',
#  'frame0095.png',
#  'frame0096.png',
#  'frame0097.png',
#  'frame0098.png',
#  'frame0099.png',
#  'frame0100.png',
#  'frame0101.png',
#  'frame0102.png',
#  'frame0103.png',
#  'frame0104.png',
#  'frame0105.png',
#  'frame0106.png',
#  'frame0107.png',
#  'frame0108.png',
#  'frame0109.png',
#  'frame0110.png',
#  'frame0111.png',
#  'frame0112.png',
#  'frame0113.png',
#  'frame0114.png',
#  'frame0115.png',
#  'frame0116.png',
#  'frame0117.png',
#  'frame0118.png',
#  'frame0119.png',
#  'frame0120.png',
#  'frame0121.png',
#  'frame0122.png',
#  'frame0123.png',
#  'frame0124.png',
#  'frame0125.png',
#  'frame0126.png',
#  'frame0127.png',
#  'frame0128.png',
#  'frame0129.png',
#  'frame0130.png',
#  'frame0131.png',
#  'frame0132.png',
#  'frame0133.png',
#  'frame0134.png',
#  'frame0135.png',
#  'frame0136.png',
#  'frame0137.png',
#  'frame0138.png',
#  'frame0139.png',
#  'frame0140.png',
#  'frame0141.png',
#  'frame0142.png',
#  'frame0143.png',
#  'frame0144.png',
#  'frame0145.png',
#  'frame0146.png',
#  'frame0147.png',
#  'frame0148.png',
#  'frame0149.png',
#  'frame0150.png',
#  'frame0151.png',
#  'frame0152.png',
#  'frame0153.png',
#  'frame0154.png',
#  'frame0155.png',
#  'frame0156.png',
#  'frame0157.png',
#  'frame0158.png',
#  'frame0159.png',
#  'frame0160.png',
#  'frame0161.png',
#  'frame0162.png',
#  'frame0163.png',
#  'frame0164.png',
#  'frame0165.png',
#  'frame0166.png',
#  'frame0167.png',
#  'frame0168.png',
#  'frame0169.png',
#  'frame0170.png',
#  'frame0171.png',
#  'frame0172.png',
#  'frame0173.png',
#  'frame0174.png',
#  'frame0175.png',
#  'frame0176.png',
#  'frame0177.png',
#  'frame0178.png',
#  'frame0179.png',
#  'frame0180.png',
#  'frame0181.png',
#  'frame0182.png',
#  'frame0183.png',
#  'frame0184.png',
#  'frame0185.png',
#  'frame0186.png',
#  'frame0187.png',
#  'frame0188.png',
#  'frame0189.png',
#  'frame0190.png',
#  'frame0191.png',
#  'frame0192.png',
#  'frame0193.png',
#  'frame0194.png',
#  'frame0195.png',
#  'frame0196.png',
#  'frame0197.png',
#  'frame0198.png',
#  'frame0199.png',
#  'frame0200.png',
#  'frame0201.png',
#  'frame0202.png',
#  'frame0203.png',
#  'frame0204.png',
#  'frame0205.png',
#  'frame0206.png',
#  'frame0207.png',
#  'frame0208.png',
#  'frame0209.png',
#  'frame0210.png',
#  'frame0211.png',
#  'frame0212.png',
#  'frame0213.png',
#  'frame0214.png',
#  'frame0215.png',
#  'frame0216.png',
#  'frame0217.png',
#  'frame0218.png',
#  'frame0219.png',
#  'frame0220.png',
#  'frame0221.png',
#  'frame0222.png',
#  'frame0223.png',
#  'frame0224.png',
#  'frame0225.png',
#  'frame0226.png',
#  'frame0227.png',
#  'frame0228.png',
#  'frame0229.png',
#  'frame0230.png',
#  'frame0231.png',
#  'frame0232.png',
#  'frame0233.png',
#  'frame0234.png',
#  'frame0235.png',
#  'frame0236.png',
#  'frame0237.png',
#  'frame0238.png',
#  'frame0239.png',
#  'frame0240.png',
#  'frame0241.png',
#  'frame0242.png',
#  'frame0243.png',
#  'frame0244.png',
#  'frame0245.png',
#  'frame0246.png',
#  'frame0247.png',
#  'frame0248.png',
#  'frame0249.png',
#  'frame0250.png',
#  'frame0251.png',
#  'frame0252.png',
#  'frame0253.png',
#  'frame0254.png',
#  'frame0255.png',
#  'frame0256.png',
#  'frame0257.png',
#  'frame0258.png',
#  'frame0259.png',
#  'frame0260.png',
#  'frame0261.png',
#  'frame0262.png',
#  'frame0263.png',
#  'frame0264.png',
#  'frame0265.png',
#  'frame0266.png',
#  'frame0267.png',
#  'frame0268.png',
#  'frame0269.png',
#  'frame0270.png',
#  'frame0271.png',
#  'frame0272.png',
#  'frame0273.png',
#  'frame0274.png',
#  'frame0275.png',
#  'frame0276.png',
#  'frame0277.png',
#  'frame0278.png',
#  'frame0279.png',
#  'frame0280.png',
#  'frame0281.png',
#  'frame0282.png',
#  'frame0283.png',
#  'frame0284.png',
#  'frame0285.png',
#  'frame0286.png',
#  'frame0287.png',
#  'frame0288.png',
#  'frame0289.png',
#  'frame0290.png',
#  'frame0291.png',
#  'frame0292.png',
#  'frame0293.png',
#  'frame0294.png',
#  'frame0295.png',
#  'frame0296.png',
#  'frame0297.png',
#  'frame0298.png',
#  'frame0299.png',
#  'frame0300.png',
#  'frame0301.png',
#  'frame0302.png',
#  'frame0303.png',
#  'frame0304.png',
#  'frame0305.png',
#  'frame0306.png',
#  'frame0307.png',
#  'frame0308.png',
#  'frame0309.png',
#  'frame0310.png',
#  'frame0311.png',
#  'frame0312.png',
#  'frame0313.png',
#  'frame0314.png',
#  'frame0315.png',
#  'frame0316.png',
#  'frame0317.png',
#  'frame0318.png',
#  'frame0319.png',
#  'frame0320.png',
#  'frame0321.png',
#  'frame0322.png',
#  'frame0323.png',
#  'frame0324.png',
#  'frame0325.png',
#  'frame0326.png',
#  'frame0327.png',
#  'frame0328.png',
#  'frame0329.png',
#  'frame0330.png',
#  'frame0331.png',
#  'frame0332.png',
#  'frame0333.png',
#  'frame0334.png',
#  'frame0335.png',
#  'frame0336.png',
#  'frame0337.png',
#  'frame0338.png',
#  'frame0339.png',
#  'frame0340.png',
#  'frame0341.png',
#  'frame0342.png',
#  'frame0343.png',
#  'frame0344.png',
#  'frame0345.png',
#  'frame0346.png',
#  'frame0347.png',
#  'frame0348.png',
#  'frame0349.png',
#  'frame0350.png',
#  'frame0351.png',
#  'frame0352.png',
#  'frame0353.png',
#  'frame0354.png',
#  'frame0355.png',
#  'frame0356.png',
#  'frame0357.png',
#  'frame0358.png',
#  'frame0359.png',
#  'frame0360.png',
#  'frame0361.png',
#  'frame0362.png',
#  'frame0363.png',
#  'frame0364.png',
#  'frame0365.png',
#  'frame0366.png',
#  'frame0367.png',
#  'frame0368.png',
#  'frame0369.png',
#  'frame0370.png',
#  'frame0371.png',
#  'frame0372.png',
#  'frame0373.png',
#  'frame0374.png',
#  'frame0375.png',
#  'frame0376.png',
#  'frame0377.png',
#  'frame0378.png',
#  'frame0379.png',
#  'frame0380.png',
#  'frame0381.png',
#  'frame0382.png',
#  'frame0383.png',
#  'frame0384.png',
#  'frame0385.png',
#  'frame0386.png',
#  'frame0387.png',
#  'frame0388.png',
#  'frame0389.png',
#  'frame0390.png',
#  'frame0391.png',
#  'frame0392.png',
#  'frame0393.png',
#  'frame0394.png',
#  'frame0395.png',
#  'frame0396.png',
#  'frame0397.png',
#  'frame0398.png',
#  'frame0399.png',
#  'frame0400.png',
#  'frame0401.png',
#  'frame0402.png',
#  'frame0403.png',
#  'frame0404.png',
#  'frame0405.png',
#  'frame0406.png',
#  'frame0407.png',
#  'frame0408.png',
#  'frame0409.png',
#  'frame0410.png',
#  'frame0411.png',
#  'frame0412.png',
#  'frame0413.png',
#  'frame0414.png',
#  'frame0415.png',
#  'frame0416.png',
#  'frame0417.png',
#  'frame0418.png',
#  'frame0419.png',
#  'frame0420.png',
#  'frame0421.png',
#  'frame0422.png',
#  'frame0423.png',
#  'frame0424.png',
#  'frame0425.png',
#  'frame0426.png',
#  'frame0427.png',
#  'frame0428.png',
#  'frame0429.png',
#  'frame0430.png',
#  'frame0431.png',
#  'frame0432.png',
#  'frame0433.png',
#  'frame0434.png',
#  'frame0435.png',
#  'frame0436.png',
#  'frame0437.png',
#  'frame0438.png',
#  'frame0439.png',
#  'frame0440.png',
#  'frame0441.png',
#  'frame0442.png',
#  'frame0443.png',
#  'frame0444.png',
#  'frame0445.png',
#  'frame0446.png',
#  'frame0447.png',
#  'frame0448.png',
#  'frame0449.png',
#  'frame0450.png',
#  'frame0451.png',
#  'frame0452.png',
#  'frame0453.png',
#  'frame0454.png',
#  'frame0455.png',
#  'frame0456.png',
#  'frame0457.png',
#  'frame0458.png',
#  'frame0459.png',
#  'frame0460.png',
#  'frame0461.png',
#  'frame0462.png',
#  'frame0463.png',
#  'frame0464.png',
#  'frame0465.png',
#  'frame0466.png',
#  'frame0467.png',
#  'frame0468.png',
#  'frame0469.png',
#  'frame0470.png',
#  'frame0471.png',
#  'frame0472.png',
#  'frame0473.png',
#  'frame0474.png',
#  'frame0475.png',
#  'frame0476.png',
#  'frame0477.png',
#  'frame0478.png',
#  'frame0479.png',
#  'frame0480.png',
#  'frame0481.png',
#  'frame0482.png',
#  'frame0483.png',
#  'frame0484.png',
#  'frame0485.png',
#  'frame0486.png',
#  'frame0487.png',
#  'frame0488.png',
#  'frame0489.png',
#  'frame0490.png',
#  'frame0491.png',
#  'frame0492.png',
#  'frame0493.png',
#  'frame0494.png',
#  'frame0495.png',
#  'frame0496.png',
#  'frame0497.png',
#  'frame0498.png',
#  'frame0499.png',
#  'frame0500.png',
#  'frame0501.png',
#  'frame0502.png',
#  'frame0503.png',
#  'frame0504.png',
#  'frame0505.png',
#  'frame0506.png',
#  'frame0507.png',
#  'frame0508.png',
#  'frame0509.png',
#  'frame0510.png',
#  'frame0511.png',
#  'frame0512.png',
#  'frame0513.png',
#  'frame0514.png',
#  'frame0515.png',
#  'frame0516.png',
#  'frame0517.png',
#  'frame0518.png',
#  'frame0519.png',
#  'frame0520.png',
#  'frame0521.png',
#  'frame0522.png',
#  'frame0523.png',
#  'frame0524.png',
#  'frame0525.png',
#  'frame0526.png',
#  'frame0527.png',
#  'frame0528.png',
#  'frame0529.png',
#  'frame0530.png',
#  'frame0531.png',
#  'frame0532.png',
#  'frame0533.png',
#  'frame0534.png',
#  'frame0535.png',
#  'frame0536.png',
#  'frame0537.png',
#  'frame0538.png',
#  'frame0539.png',
#  'frame0540.png',
#  'frame0541.png',
#  'frame0542.png',
#  'frame0543.png',
#  'frame0544.png',
#  'frame0545.png',
#  'frame0546.png',
#  'frame0547.png',
#  'frame0548.png',
#  'frame0549.png',
#  'frame0550.png',
#  'frame0551.png',
#  'frame0552.png',
#  'frame0553.png',
#  'frame0554.png',
#  'frame0555.png',
#  'frame0556.png',
#  'frame0557.png',
#  'frame0558.png',
#  'frame0559.png',
#  'frame0560.png',
#  'frame0561.png',
#  'frame0562.png',
#  'frame0563.png',
#  'frame0564.png',
#  'frame0565.png',
#  'frame0566.png',
#  'frame0567.png',
#  'frame0568.png',
#  'frame0569.png',
#  'frame0570.png',
#  'frame0571.png',
#  'frame0572.png',
#  'frame0573.png',
#  'frame0574.png',
#  'frame0575.png',
#  'frame0576.png',
#  'frame0577.png',
#  'frame0578.png',
#  'frame0579.png',
#  'frame0580.png',
#  'frame0581.png',
#  'frame0582.png',
#  'frame0583.png',
#  'frame0584.png',
#  'frame0585.png',
#  'frame0586.png',
#  'frame0587.png',
#  'frame0588.png',
#  'frame0589.png',
#  'frame0590.png',
#  'frame0591.png',
#  'frame0592.png',
#  'frame0593.png',
#  'frame0594.png',
#  'frame0595.png',
#  'frame0596.png',
#  'frame0597.png',
#  'frame0598.png',
#  'frame0599.png',
#  'frame0600.png',
#  'frame0601.png',
#  'frame0602.png',
#  'frame0603.png',
#  'frame0604.png',
#  'frame0605.png',
#  'frame0606.png',
#  'frame0607.png',
#  'frame0608.png',
#  'frame0609.png',
#  'frame0610.png',
#  'frame0611.png',
#  'frame0612.png',
#  'frame0613.png',
#  'frame0614.png',
#  'frame0615.png',
#  'frame0616.png',
#  'frame0617.png',
#  'frame0618.png',
#  'frame0619.png',
#  'frame0620.png',
#  'frame0621.png',
#  'frame0622.png',
#  'frame0623.png',
#  'frame0624.png',
#  'frame0625.png',
#  'frame0626.png',
#  'frame0627.png',
#  'frame0628.png',
#  'frame0629.png',
#  'frame0630.png',
#  'frame0631.png',
#  'frame0632.png',
#  'frame0633.png',
#  'frame0634.png',
#  'frame0635.png',
#  'frame0636.png',
#  'frame0637.png',
#  'frame0638.png',
#  'frame0639.png',
#  'frame0640.png',
#  'frame0641.png',
#  'frame0642.png',
#  'frame0643.png',
#  'frame0644.png',
#  'frame0645.png',
#  'frame0646.png',
#  'frame0647.png',
#  'frame0648.png',
#  'frame0649.png',
#  'frame0650.png',
#  'frame0651.png',
#  'frame0652.png',
#  'frame0653.png',
#  'frame0654.png',
#  'frame0655.png',
#  'frame0656.png',
#  'frame0657.png',
#  'frame0658.png',
#  'frame0659.png',
#  'frame0660.png',
#  'frame0661.png',
#  'frame0662.png',
#  'frame0663.png',
#  'frame0664.png',
#  'frame0665.png',
#  'frame0666.png',
#  'frame0667.png',
#  'frame0668.png',
#  'frame0669.png',
#  'frame0670.png',
#  'frame0671.png',
#  'frame0672.png',
#  'frame0673.png',
#  'frame0674.png',
#  'frame0675.png',
#  'frame0676.png',
#  'frame0677.png',
#  'frame0678.png',
#  'frame0679.png',
#  'frame0680.png',
#  'frame0681.png',
#  'frame0682.png',
#  'frame0683.png',
#  'frame0684.png',
#  'frame0685.png',
#  'frame0686.png',
#  'frame0687.png',
#  'frame0688.png',
#  'frame0689.png',
#  'frame0690.png',
#  'frame0691.png',
#  'frame0692.png',
#  'frame0693.png',
#  'frame0694.png',
#  'frame0695.png',
#  'frame0696.png',
#  'frame0697.png',
#  'frame0698.png',
#  'frame0699.png',
#  'frame0700.png',
#  'frame0701.png',
#  'frame0702.png',
#  'frame0703.png',
#  'frame0704.png',
#  'frame0705.png',
#  'frame0706.png',
#  'frame0707.png',
#  'frame0708.png',
#  'frame0709.png',
#  'frame0710.png',
#  'frame0711.png',
#  'frame0712.png',
#  'frame0713.png',
#  'frame0714.png',
#  'frame0715.png',
#  'frame0716.png',
#  'frame0717.png',
#  'frame0718.png',
#  'frame0719.png',
#  'frame0720.png',
#  'frame0721.png',
#  'frame0722.png',
#  'frame0723.png',
#  'frame0724.png',
#  'frame0725.png',
#  'frame0726.png',
#  'frame0727.png',
#  'frame0728.png',
#  'frame0729.png',
#  'frame0730.png',
#  'frame0731.png',
#  'frame0732.png',
#  'frame0733.png',
#  'frame0734.png',
#  'frame0735.png',
#  'frame0736.png',
#  'frame0737.png',
#  'frame0738.png',
#  'frame0739.png',
#  'frame0740.png',
#  'frame0741.png',
#  'frame0742.png',
#  'frame0743.png',
#  'frame0744.png',
#  'frame0745.png',
#  'frame0746.png',
#  'frame0747.png',
#  'frame0748.png',
#  'frame0749.png',
#  'frame0750.png',
#  'frame0751.png',
#  'frame0752.png',
#  'frame0753.png',
#  'frame0754.png',
#  'frame0755.png',
#  'frame0756.png',
#  'frame0757.png',
#  'frame0758.png',
#  'frame0759.png',
#  'frame0760.png',
#  'frame0761.png',
#  'frame0762.png',
#  'frame0763.png',
#  'frame0764.png',
#  'frame0765.png']

# %%
#frames_list.sort()
#print(len(frames_list))
train_masks_list
# Out:
# ['frame0000_L.png',
#  'frame0001_L.png',
#  'frame0002_L.png',
#  'frame0003_L.png',
#  'frame0004_L.png',
#  'frame0005_L.png',
#  'frame0006_L.png',
#  'frame0007_L.png',
#  'frame0008_L.png',
#  'frame0009_L.png',
#  'frame0010_L.png',
#  'frame0011_L.png',
#  'frame0012_L.png',
#  'frame0013_L.png',
#  'frame0014_L.png',
#  'frame0015_L.png',
#  'frame0016_L.png',
#  'frame0017_L.png',
#  'frame0018_L.png',
#  'frame0019_L.png',
#  'frame0020_L.png',
#  'frame0021_L.png',
#  'frame0022_L.png',
#  'frame0023_L.png',
#  'frame0024_L.png',
#  'frame0025_L.png',
#  'frame0026_L.png',
#  'frame0027_L.png',
#  'frame0028_L.png',
#  'frame0029_L.png',
#  'frame0030_L.png',
#  'frame0031_L.png',
#  'frame0032_L.png',
#  'frame0033_L.png',
#  'frame0034_L.png',
#  'frame0035_L.png',
#  'frame0036_L.png',
#  'frame0037_L.png',
#  'frame0038_L.png',
#  'frame0039_L.png',
#  'frame0040_L.png',
#  'frame0041_L.png',
#  'frame0042_L.png',
#  'frame0043_L.png',
#  'frame0044_L.png',
#  'frame0045_L.png',
#  'frame0046_L.png',
#  'frame0047_L.png',
#  'frame0048_L.png',
#  'frame0049_L.png',
#  'frame0050_L.png',
#  'frame0051_L.png',
#  'frame0052_L.png',
#  'frame0053_L.png',
#  'frame0054_L.png',
#  'frame0055_L.png',
#  'frame0056_L.png',
#  'frame0057_L.png',
#  'frame0058_L.png',
#  'frame0059_L.png',
#  'frame0060_L.png',
#  'frame0061_L.png',
#  'frame0062_L.png',
#  'frame0063_L.png',
#  'frame0064_L.png',
#  'frame0065_L.png',
#  'frame0066_L.png',
#  'frame0067_L.png',
#  'frame0068_L.png',
#  'frame0069_L.png',
#  'frame0070_L.png',
#  'frame0071_L.png',
#  'frame0072_L.png',
#  'frame0073_L.png',
#  'frame0074_L.png',
#  'frame0075_L.png',
#  'frame0076_L.png',
#  'frame0077_L.png',
#  'frame0078_L.png',
#  'frame0079_L.png',
#  'frame0080_L.png',
#  'frame0081_L.png',
#  'frame0082_L.png',
#  'frame0083_L.png',
#  'frame0084_L.png',
#  'frame0085_L.png',
#  'frame0086_L.png',
#  'frame0087_L.png',
#  'frame0088_L.png',
#  'frame0089_L.png',
#  'frame0090_L.png',
#  'frame0091_L.png',
#  'frame0092_L.png',
#  'frame0093_L.png',
#  'frame0094_L.png',
#  'frame0095_L.png',
#  'frame0096_L.png',
#  'frame0097_L.png',
#  'frame0098_L.png',
#  'frame0099_L.png',
#  'frame0100_L.png',
#  'frame0101_L.png',
#  'frame0102_L.png',
#  'frame0103_L.png',
#  'frame0104_L.png',
#  'frame0105_L.png',
#  'frame0106_L.png',
#  'frame0107_L.png',
#  'frame0108_L.png',
#  'frame0109_L.png',
#  'frame0110_L.png',
#  'frame0111_L.png',
#  'frame0112_L.png',
#  'frame0113_L.png',
#  'frame0114_L.png',
#  'frame0115_L.png',
#  'frame0116_L.png',
#  'frame0117_L.png',
#  'frame0118_L.png',
#  'frame0119_L.png',
#  'frame0120_L.png',
#  'frame0121_L.png',
#  'frame0122_L.png',
#  'frame0123_L.png',
#  'frame0124_L.png',
#  'frame0125_L.png',
#  'frame0126_L.png',
#  'frame0127_L.png',
#  'frame0128_L.png',
#  'frame0129_L.png',
#  'frame0130_L.png',
#  'frame0131_L.png',
#  'frame0132_L.png',
#  'frame0133_L.png',
#  'frame0134_L.png',
#  'frame0135_L.png',
#  'frame0136_L.png',
#  'frame0137_L.png',
#  'frame0138_L.png',
#  'frame0139_L.png',
#  'frame0140_L.png',
#  'frame0141_L.png',
#  'frame0142_L.png',
#  'frame0143_L.png',
#  'frame0144_L.png',
#  'frame0145_L.png',
#  'frame0146_L.png',
#  'frame0147_L.png',
#  'frame0148_L.png',
#  'frame0149_L.png',
#  'frame0150_L.png',
#  'frame0151_L.png',
#  'frame0152_L.png',
#  'frame0153_L.png',
#  'frame0154_L.png',
#  'frame0155_L.png',
#  'frame0156_L.png',
#  'frame0157_L.png',
#  'frame0158_L.png',
#  'frame0159_L.png',
#  'frame0160_L.png',
#  'frame0161_L.png',
#  'frame0162_L.png',
#  'frame0163_L.png',
#  'frame0164_L.png',
#  'frame0165_L.png',
#  'frame0166_L.png',
#  'frame0167_L.png',
#  'frame0168_L.png',
#  'frame0169_L.png',
#  'frame0170_L.png',
#  'frame0171_L.png',
#  'frame0172_L.png',
#  'frame0173_L.png',
#  'frame0174_L.png',
#  'frame0175_L.png',
#  'frame0176_L.png',
#  'frame0177_L.png',
#  'frame0178_L.png',
#  'frame0179_L.png',
#  'frame0180_L.png',
#  'frame0181_L.png',
#  'frame0182_L.png',
#  'frame0183_L.png',
#  'frame0184_L.png',
#  'frame0185_L.png',
#  'frame0186_L.png',
#  'frame0187_L.png',
#  'frame0188_L.png',
#  'frame0189_L.png',
#  'frame0190_L.png',
#  'frame0191_L.png',
#  'frame0192_L.png',
#  'frame0193_L.png',
#  'frame0194_L.png',
#  'frame0195_L.png',
#  'frame0196_L.png',
#  'frame0197_L.png',
#  'frame0198_L.png',
#  'frame0199_L.png',
#  'frame0200_L.png',
#  'frame0201_L.png',
#  'frame0202_L.png',
#  'frame0203_L.png',
#  'frame0204_L.png',
#  'frame0205_L.png',
#  'frame0206_L.png',
#  'frame0207_L.png',
#  'frame0208_L.png',
#  'frame0209_L.png',
#  'frame0210_L.png',
#  'frame0211_L.png',
#  'frame0212_L.png',
#  'frame0213_L.png',
#  'frame0214_L.png',
#  'frame0215_L.png',
#  'frame0216_L.png',
#  'frame0217_L.png',
#  'frame0218_L.png',
#  'frame0219_L.png',
#  'frame0220_L.png',
#  'frame0221_L.png',
#  'frame0222_L.png',
#  'frame0223_L.png',
#  'frame0224_L.png',
#  'frame0225_L.png',
#  'frame0226_L.png',
#  'frame0227_L.png',
#  'frame0228_L.png',
#  'frame0229_L.png',
#  'frame0230_L.png',
#  'frame0231_L.png',
#  'frame0232_L.png',
#  'frame0233_L.png',
#  'frame0234_L.png',
#  'frame0235_L.png',
#  'frame0236_L.png',
#  'frame0237_L.png',
#  'frame0238_L.png',
#  'frame0239_L.png',
#  'frame0240_L.png',
#  'frame0241_L.png',
#  'frame0242_L.png',
#  'frame0243_L.png',
#  'frame0244_L.png',
#  'frame0245_L.png',
#  'frame0246_L.png',
#  'frame0247_L.png',
#  'frame0248_L.png',
#  'frame0249_L.png',
#  'frame0250_L.png',
#  'frame0251_L.png',
#  'frame0252_L.png',
#  'frame0253_L.png',
#  'frame0254_L.png',
#  'frame0255_L.png',
#  'frame0256_L.png',
#  'frame0257_L.png',
#  'frame0258_L.png',
#  'frame0259_L.png',
#  'frame0260_L.png',
#  'frame0261_L.png',
#  'frame0262_L.png',
#  'frame0263_L.png',
#  'frame0264_L.png',
#  'frame0265_L.png',
#  'frame0266_L.png',
#  'frame0267_L.png',
#  'frame0268_L.png',
#  'frame0269_L.png',
#  'frame0270_L.png',
#  'frame0271_L.png',
#  'frame0272_L.png',
#  'frame0273_L.png',
#  'frame0274_L.png',
#  'frame0275_L.png',
#  'frame0276_L.png',
#  'frame0277_L.png',
#  'frame0278_L.png',
#  'frame0279_L.png',
#  'frame0280_L.png',
#  'frame0281_L.png',
#  'frame0282_L.png',
#  'frame0283_L.png',
#  'frame0284_L.png',
#  'frame0285_L.png',
#  'frame0286_L.png',
#  'frame0287_L.png',
#  'frame0288_L.png',
#  'frame0289_L.png',
#  'frame0290_L.png',
#  'frame0291_L.png',
#  'frame0292_L.png',
#  'frame0293_L.png',
#  'frame0294_L.png',
#  'frame0295_L.png',
#  'frame0296_L.png',
#  'frame0297_L.png',
#  'frame0298_L.png',
#  'frame0299_L.png',
#  'frame0300_L.png',
#  'frame0301_L.png',
#  'frame0302_L.png',
#  'frame0303_L.png',
#  'frame0304_L.png',
#  'frame0305_L.png',
#  'frame0306_L.png',
#  'frame0307_L.png',
#  'frame0308_L.png',
#  'frame0309_L.png',
#  'frame0310_L.png',
#  'frame0311_L.png',
#  'frame0312_L.png',
#  'frame0313_L.png',
#  'frame0314_L.png',
#  'frame0315_L.png',
#  'frame0316_L.png',
#  'frame0317_L.png',
#  'frame0318_L.png',
#  'frame0319_L.png',
#  'frame0320_L.png',
#  'frame0321_L.png',
#  'frame0322_L.png',
#  'frame0323_L.png',
#  'frame0324_L.png',
#  'frame0325_L.png',
#  'frame0326_L.png',
#  'frame0327_L.png',
#  'frame0328_L.png',
#  'frame0329_L.png',
#  'frame0330_L.png',
#  'frame0331_L.png',
#  'frame0332_L.png',
#  'frame0333_L.png',
#  'frame0334_L.png',
#  'frame0335_L.png',
#  'frame0336_L.png',
#  'frame0337_L.png',
#  'frame0338_L.png',
#  'frame0339_L.png',
#  'frame0340_L.png',
#  'frame0341_L.png',
#  'frame0342_L.png',
#  'frame0343_L.png',
#  'frame0344_L.png',
#  'frame0345_L.png',
#  'frame0346_L.png',
#  'frame0347_L.png',
#  'frame0348_L.png',
#  'frame0349_L.png',
#  'frame0350_L.png',
#  'frame0351_L.png',
#  'frame0352_L.png',
#  'frame0353_L.png',
#  'frame0354_L.png',
#  'frame0355_L.png',
#  'frame0356_L.png',
#  'frame0357_L.png',
#  'frame0358_L.png',
#  'frame0359_L.png',
#  'frame0360_L.png',
#  'frame0361_L.png',
#  'frame0362_L.png',
#  'frame0363_L.png',
#  'frame0364_L.png',
#  'frame0365_L.png',
#  'frame0366_L.png',
#  'frame0367_L.png',
#  'frame0368_L.png',
#  'frame0369_L.png',
#  'frame0370_L.png',
#  'frame0371_L.png',
#  'frame0372_L.png',
#  'frame0373_L.png',
#  'frame0374_L.png',
#  'frame0375_L.png',
#  'frame0376_L.png',
#  'frame0377_L.png',
#  'frame0378_L.png',
#  'frame0379_L.png',
#  'frame0380_L.png',
#  'frame0381_L.png',
#  'frame0382_L.png',
#  'frame0383_L.png',
#  'frame0384_L.png',
#  'frame0385_L.png',
#  'frame0386_L.png',
#  'frame0387_L.png',
#  'frame0388_L.png',
#  'frame0389_L.png',
#  'frame0390_L.png',
#  'frame0391_L.png',
#  'frame0392_L.png',
#  'frame0393_L.png',
#  'frame0394_L.png',
#  'frame0395_L.png',
#  'frame0396_L.png',
#  'frame0397_L.png',
#  'frame0398_L.png',
#  'frame0399_L.png',
#  'frame0400_L.png',
#  'frame0401_L.png',
#  'frame0402_L.png',
#  'frame0403_L.png',
#  'frame0404_L.png',
#  'frame0405_L.png',
#  'frame0406_L.png',
#  'frame0407_L.png',
#  'frame0408_L.png',
#  'frame0409_L.png',
#  'frame0410_L.png',
#  'frame0411_L.png',
#  'frame0412_L.png',
#  'frame0413_L.png',
#  'frame0414_L.png',
#  'frame0415_L.png',
#  'frame0416_L.png',
#  'frame0417_L.png',
#  'frame0418_L.png',
#  'frame0419_L.png',
#  'frame0420_L.png',
#  'frame0421_L.png',
#  'frame0422_L.png',
#  'frame0423_L.png',
#  'frame0424_L.png',
#  'frame0425_L.png',
#  'frame0426_L.png',
#  'frame0427_L.png',
#  'frame0428_L.png',
#  'frame0429_L.png',
#  'frame0430_L.png',
#  'frame0431_L.png',
#  'frame0432_L.png',
#  'frame0433_L.png',
#  'frame0434_L.png',
#  'frame0435_L.png',
#  'frame0436_L.png',
#  'frame0437_L.png',
#  'frame0438_L.png',
#  'frame0439_L.png',
#  'frame0440_L.png',
#  'frame0441_L.png',
#  'frame0442_L.png',
#  'frame0443_L.png',
#  'frame0444_L.png',
#  'frame0445_L.png',
#  'frame0446_L.png',
#  'frame0447_L.png',
#  'frame0448_L.png',
#  'frame0449_L.png',
#  'frame0450_L.png',
#  'frame0451_L.png',
#  'frame0452_L.png',
#  'frame0453_L.png',
#  'frame0454_L.png',
#  'frame0455_L.png',
#  'frame0456_L.png',
#  'frame0457_L.png',
#  'frame0458_L.png',
#  'frame0459_L.png',
#  'frame0460_L.png',
#  'frame0461_L.png',
#  'frame0462_L.png',
#  'frame0463_L.png',
#  'frame0464_L.png',
#  'frame0465_L.png',
#  'frame0466_L.png',
#  'frame0467_L.png',
#  'frame0468_L.png',
#  'frame0469_L.png',
#  'frame0470_L.png',
#  'frame0471_L.png',
#  'frame0472_L.png',
#  'frame0473_L.png',
#  'frame0474_L.png',
#  'frame0475_L.png',
#  'frame0476_L.png',
#  'frame0477_L.png',
#  'frame0478_L.png',
#  'frame0479_L.png',
#  'frame0480_L.png',
#  'frame0481_L.png',
#  'frame0482_L.png',
#  'frame0483_L.png',
#  'frame0484_L.png',
#  'frame0485_L.png',
#  'frame0486_L.png',
#  'frame0487_L.png',
#  'frame0488_L.png',
#  'frame0489_L.png',
#  'frame0490_L.png',
#  'frame0491_L.png',
#  'frame0492_L.png',
#  'frame0493_L.png',
#  'frame0494_L.png',
#  'frame0495_L.png',
#  'frame0496_L.png',
#  'frame0497_L.png',
#  'frame0498_L.png',
#  'frame0499_L.png',
#  'frame0500_L.png',
#  'frame0501_L.png',
#  'frame0502_L.png',
#  'frame0503_L.png',
#  'frame0504_L.png',
#  'frame0505_L.png',
#  'frame0506_L.png',
#  'frame0507_L.png',
#  'frame0508_L.png',
#  'frame0509_L.png',
#  'frame0510_L.png',
#  'frame0511_L.png',
#  'frame0512_L.png',
#  'frame0513_L.png',
#  'frame0514_L.png',
#  'frame0515_L.png',
#  'frame0516_L.png',
#  'frame0517_L.png',
#  'frame0518_L.png',
#  'frame0519_L.png',
#  'frame0520_L.png',
#  'frame0521_L.png',
#  'frame0522_L.png',
#  'frame0523_L.png',
#  'frame0524_L.png',
#  'frame0525_L.png',
#  'frame0526_L.png',
#  'frame0527_L.png',
#  'frame0528_L.png',
#  'frame0529_L.png',
#  'frame0530_L.png',
#  'frame0531_L.png',
#  'frame0532_L.png',
#  'frame0533_L.png',
#  'frame0534_L.png',
#  'frame0535_L.png',
#  'frame0536_L.png',
#  'frame0537_L.png',
#  'frame0538_L.png',
#  'frame0539_L.png',
#  'frame0540_L.png',
#  'frame0541_L.png',
#  'frame0542_L.png',
#  'frame0543_L.png',
#  'frame0544_L.png',
#  'frame0545_L.png',
#  'frame0546_L.png',
#  'frame0547_L.png',
#  'frame0548_L.png',
#  'frame0549_L.png',
#  'frame0550_L.png',
#  'frame0551_L.png',
#  'frame0552_L.png',
#  'frame0553_L.png',
#  'frame0554_L.png',
#  'frame0555_L.png',
#  'frame0556_L.png',
#  'frame0557_L.png',
#  'frame0558_L.png',
#  'frame0559_L.png',
#  'frame0560_L.png',
#  'frame0561_L.png',
#  'frame0562_L.png',
#  'frame0563_L.png',
#  'frame0564_L.png',
#  'frame0565_L.png',
#  'frame0566_L.png',
#  'frame0567_L.png',
#  'frame0568_L.png',
#  'frame0569_L.png',
#  'frame0570_L.png',
#  'frame0571_L.png',
#  'frame0572_L.png',
#  'frame0573_L.png',
#  'frame0574_L.png',
#  'frame0575_L.png',
#  'frame0576_L.png',
#  'frame0577_L.png',
#  'frame0578_L.png',
#  'frame0579_L.png',
#  'frame0580_L.png',
#  'frame0581_L.png',
#  'frame0582_L.png',
#  'frame0583_L.png',
#  'frame0584_L.png',
#  'frame0585_L.png',
#  'frame0586_L.png',
#  'frame0587_L.png',
#  'frame0588_L.png',
#  'frame0589_L.png',
#  'frame0590_L.png',
#  'frame0591_L.png',
#  'frame0592_L.png',
#  'frame0593_L.png',
#  'frame0594_L.png',
#  'frame0595_L.png',
#  'frame0596_L.png',
#  'frame0597_L.png',
#  'frame0598_L.png',
#  'frame0599_L.png',
#  'frame0600_L.png',
#  'frame0601_L.png',
#  'frame0602_L.png',
#  'frame0603_L.png',
#  'frame0604_L.png',
#  'frame0605_L.png',
#  'frame0606_L.png',
#  'frame0607_L.png',
#  'frame0608_L.png',
#  'frame0609_L.png',
#  'frame0610_L.png',
#  'frame0611_L.png',
#  'frame0612_L.png',
#  'frame0613_L.png',
#  'frame0614_L.png',
#  'frame0615_L.png',
#  'frame0616_L.png',
#  'frame0617_L.png',
#  'frame0618_L.png',
#  'frame0619_L.png',
#  'frame0620_L.png',
#  'frame0621_L.png',
#  'frame0622_L.png',
#  'frame0623_L.png',
#  'frame0624_L.png',
#  'frame0625_L.png',
#  'frame0626_L.png',
#  'frame0627_L.png',
#  'frame0628_L.png',
#  'frame0629_L.png',
#  'frame0630_L.png',
#  'frame0631_L.png',
#  'frame0632_L.png',
#  'frame0633_L.png',
#  'frame0634_L.png',
#  'frame0635_L.png',
#  'frame0636_L.png',
#  'frame0637_L.png',
#  'frame0638_L.png',
#  'frame0639_L.png',
#  'frame0640_L.png',
#  'frame0641_L.png',
#  'frame0642_L.png',
#  'frame0643_L.png',
#  'frame0644_L.png',
#  'frame0645_L.png',
#  'frame0646_L.png',
#  'frame0647_L.png',
#  'frame0648_L.png',
#  'frame0649_L.png',
#  'frame0650_L.png',
#  'frame0651_L.png',
#  'frame0652_L.png',
#  'frame0653_L.png',
#  'frame0654_L.png',
#  'frame0655_L.png',
#  'frame0656_L.png',
#  'frame0657_L.png',
#  'frame0658_L.png',
#  'frame0659_L.png',
#  'frame0660_L.png',
#  'frame0661_L.png',
#  'frame0662_L.png',
#  'frame0663_L.png',
#  'frame0664_L.png',
#  'frame0665_L.png',
#  'frame0666_L.png',
#  'frame0667_L.png',
#  'frame0668_L.png',
#  'frame0669_L.png',
#  'frame0670_L.png',
#  'frame0671_L.png',
#  'frame0672_L.png',
#  'frame0673_L.png',
#  'frame0674_L.png',
#  'frame0675_L.png',
#  'frame0676_L.png',
#  'frame0677_L.png',
#  'frame0678_L.png',
#  'frame0679_L.png',
#  'frame0680_L.png',
#  'frame0681_L.png',
#  'frame0682_L.png',
#  'frame0683_L.png',
#  'frame0684_L.png',
#  'frame0685_L.png',
#  'frame0686_L.png',
#  'frame0687_L.png',
#  'frame0688_L.png',
#  'frame0689_L.png',
#  'frame0690_L.png',
#  'frame0691_L.png',
#  'frame0692_L.png',
#  'frame0693_L.png',
#  'frame0694_L.png',
#  'frame0695_L.png',
#  'frame0696_L.png',
#  'frame0697_L.png',
#  'frame0698_L.png',
#  'frame0699_L.png',
#  'frame0700_L.png',
#  'frame0701_L.png',
#  'frame0702_L.png',
#  'frame0703_L.png',
#  'frame0704_L.png',
#  'frame0705_L.png',
#  'frame0706_L.png',
#  'frame0707_L.png',
#  'frame0708_L.png',
#  'frame0709_L.png',
#  'frame0710_L.png',
#  'frame0711_L.png',
#  'frame0712_L.png',
#  'frame0713_L.png',
#  'frame0714_L.png',
#  'frame0715_L.png',
#  'frame0716_L.png',
#  'frame0717_L.png',
#  'frame0718_L.png',
#  'frame0719_L.png',
#  'frame0720_L.png',
#  'frame0721_L.png',
#  'frame0722_L.png',
#  'frame0723_L.png',
#  'frame0724_L.png',
#  'frame0725_L.png',
#  'frame0726_L.png',
#  'frame0727_L.png',
#  'frame0728_L.png',
#  'frame0729_L.png',
#  'frame0730_L.png',
#  'frame0731_L.png',
#  'frame0732_L.png',
#  'frame0733_L.png',
#  'frame0734_L.png',
#  'frame0735_L.png',
#  'frame0736_L.png',
#  'frame0737_L.png',
#  'frame0738_L.png',
#  'frame0739_L.png',
#  'frame0740_L.png',
#  'frame0741_L.png',
#  'frame0742_L.png',
#  'frame0743_L.png',
#  'frame0744_L.png',
#  'frame0745_L.png',
#  'frame0746_L.png',
#  'frame0747_L.png',
#  'frame0748_L.png',
#  'frame0749_L.png',
#  'frame0750_L.png',
#  'frame0751_L.png',
#  'frame0752_L.png',
#  'frame0753_L.png',
#  'frame0754_L.png',
#  'frame0755_L.png',
#  'frame0756_L.png',
#  'frame0757_L.png',
#  'frame0758_L.png',
#  'frame0759_L.png',
#  'frame0760_L.png',
#  'frame0761_L.png',
#  'frame0762_L.png',
#  'frame0763_L.png',
#  'frame0764_L.png',
#  'frame0765_L.png']

# %% [markdown]
# ### Displaying Images in the train dataset

# %%
# Make an iterator to extract images from the tensor dataset

train_frame_batches = tf.compat.v1.data.make_one_shot_iterator(train_frame_tensors)  # outside of TF Eager, we would use make_one_shot_iterator
train_mask_batches = tf.compat.v1.data.make_one_shot_iterator(train_masks_tensors)

test_frame_batches = tf.compat.v1.data.make_one_shot_iterator(test_frame_tensors)  # outside of TF Eager, we would use make_one_shot_iterator
test_masks_tensors = tf.compat.v1.data.make_one_shot_iterator(test_masks_tensors)

# %%
n_images_to_show = 5

for i in range(n_images_to_show):
    
    # Get the next image from iterator
    frame = train_frame_batches.next().numpy().astype(np.uint8)
    mask = train_mask_batches.next().numpy().astype(np.uint8)
    
    #Plot the corresponding frames and masks
    fig = plt.figure(figsize=(20,7))
    fig.add_subplot(1,2,1)
    plt.grid(b=None)
    plt.imshow(frame)
    fig.add_subplot(1,2,2)
    plt.grid(b=None)
    plt.imshow(np.squeeze(mask))
    plt.show()

# %%
mask = train_mask_batches.next().numpy().astype(np.uint8)
mask.shape
# Out:
# (224, 224, 1)

# %% [markdown]
# ### Creating folder structure common for Computer Vision problems

# %%
DATA_PATH = '/home/lisi2020/Downloads/Multiclass-Semantic-Segmentation-CamVid-master/RedEdge'

# Create folders to hold images and masks

folders = ['train_frames/train', 'train_masks/train', 'val_frames/val', 'val_masks/val']


for folder in folders:
    try:
        os.makedirs(os.path.join(DATA_PATH, folder))
    except Exception as e: print(e)
# Out:
# [Errno 17] File exists: '/home/lisi2020/Downloads/Multiclass-Semantic-Segmentation-CamVid-master/RedEdge/train_frames/train'
# [Errno 17] File exists: '/home/lisi2020/Downloads/Multiclass-Semantic-Segmentation-CamVid-master/RedEdge/train_masks/train'
# [Errno 17] File exists: '/home/lisi2020/Downloads/Multiclass-Semantic-Segmentation-CamVid-master/RedEdge/val_frames/val'
# [Errno 17] File exists: '/home/lisi2020/Downloads/Multiclass-Semantic-Segmentation-CamVid-master/RedEdge/val_masks/val'

# %% [markdown]
# ### Saving frames and masks to correct directories

# %%
frame_batches = tf.compat.v1.data.make_one_shot_iterator(train_frame_tensors)  # outside of TF Eager, we would use make_one_shot_iterator
mask_batches = tf.compat.v1.data.make_one_shot_iterator(train_masks_tensors)

# %%
def generate_image_folder_structure(frames, masks, frames_list, masks_list, dir_name="train"):
    '''Function to save images in the appropriate folder directories 
        Inputs: 
            frames - frame tensor dataset
            masks - mask tensor dataset
            frames_list - frame file paths
            masks_list - mask file paths
    '''
    #Create iterators for frames and masks
    frame_batches = tf.compat.v1.data.make_one_shot_iterator(frames)  # outside of TF Eager, we would use make_one_shot_iterator
    mask_batches = tf.compat.v1.data.make_one_shot_iterator(masks)
    
    #Iterate over the train images while saving the frames and masks in appropriate folders
    dir_name='train'
    i=0
    for file in zip(frames_list[:-round(0.2*len(frames_list))],masks_list[:-round(0.2*len(masks_list))]):
        
        
        #Convert tensors to numpy arrays
        frame = frame_batches.next().numpy().astype(np.uint8)
        mask = mask_batches.next().numpy().astype(np.uint8)
        
        if mask.shape != (224, 224, 1):
            #Convert numpy arrays to images
            frame = Image.fromarray(frame)
            mask = Image.fromarray(mask)

            #Save frames and masks to correct directories
            frame.save(img_dir+'{}_frames/{}'.format(dir_name,dir_name)+'/'+ file[0].split(".")[0][:-3] + str(i).zfill(3) + ".png")
            mask.save(img_dir+'{}_masks/{}'.format(dir_name,dir_name)+'/'+file[1].split(".")[0][:-5] + str(i).zfill(3) + "_L.png")
            i += 1
    
    #Iterate over the val images while saving the frames and masks in appropriate folders
    dir_name='val'
    i=0
    for file in zip(frames_list[-round(0.2*len(frames_list)):],masks_list[-round(0.2*len(masks_list)):]):
        
        
        #Convert tensors to numpy arrays
        frame = frame_batches.next().numpy().astype(np.uint8)
        mask = mask_batches.next().numpy().astype(np.uint8)
        
        if mask.shape != (224, 224, 1):
            #Convert numpy arrays to images
            frame = Image.fromarray(frame)
            mask = Image.fromarray(mask)

            #Save frames and masks to correct directories
            frame.save(img_dir+'{}_frames/{}'.format(dir_name,dir_name)+'/'+ file[0].split(".")[0][:-3] + str(i).zfill(3) + ".png")
            mask.save(img_dir+'{}_masks/{}'.format(dir_name,dir_name)+'/'+file[1].split(".")[0][:-5] + str(i).zfill(3) + "_L.png")
            i += 1
    
    print("Saved {} frames to directory {}".format(len(frames_list),DATA_PATH))
    print("Saved {} masks to directory {}".format(len(masks_list),DATA_PATH))
    
    
generate_image_folder_structure(train_frame_tensors, train_masks_tensors, train_frames_list, train_masks_list)
#generate_image_folder_structure(train_frames, train_masks, val_files, 'val')
# Out:
# Saved 766 frames to directory /home/lisi2020/Downloads/Multiclass-Semantic-Segmentation-CamVid-master/RedEdge
# Saved 766 masks to directory /home/lisi2020/Downloads/Multiclass-Semantic-Segmentation-CamVid-master/RedEdge

# %% [markdown]
# ## Extract Target Class definitions

# %% [markdown]
# ### Function to parse the file "label_colors.txt" which contains the class definitions

# %%
def parse_code(l):
    '''Function to parse lines in a text file, returns separated elements (label codes and names in this case)
    '''
    if len(l.strip().split("\t")) == 2:
        a, b = l.strip().split("\t")
        return tuple(int(i) for i in a.split(' ')), b
    else:
        a, b, c = l.strip().split("\t")
        return tuple(int(i) for i in a.split(' ')), c

# %% [markdown]
# ### Parse and extract label names and codes

# %%
label_codes, label_names = zip(*[parse_code(l) for l in open(img_dir+"label_colors.txt")])
label_codes, label_names = list(label_codes), list(label_names)
label_codes[:], label_names[:]
# Out:
# ([(0, 0, 0), (255, 0, 0), (0, 255, 0)], ['Background', 'weed', 'crop'])

# %%
label_codes, label_names
# Out:
# ([(0, 0, 0), (255, 0, 0), (0, 255, 0)], ['Background', 'weed', 'crop'])

# %% [markdown]
# ### Create useful label and code conversion dictionaries
# _These will be used for:_
# - One hot encoding the mask labels for model training
# - Decoding the predicted labels for interpretation and visualization

# %%
code2id = {v:k for k,v in enumerate(label_codes)}
id2code = {k:v for k,v in enumerate(label_codes)}

# %%
name2id = {v:k for k,v in enumerate(label_names)}
id2name = {k:v for k,v in enumerate(label_names)}

# %%
id2code
# Out:
# {0: (0, 0, 0), 1: (255, 0, 0), 2: (0, 255, 0)}

# %%
id2name
# Out:
# {0: 'Background', 1: 'weed', 2: 'crop'}

# %% [markdown]
# ### Define functions for one hot encoding rgb labels, and decoding encoded predictions

# %%
def rgb_to_onehot(rgb_image, colormap = id2code):
    '''Function to one hot encode RGB mask labels
        Inputs: v
            rgb_image - image matrix (eg. 256 x 256 x 3 dimension numpy ndarray)
            colormap - dictionary of color to label id
        Output: One hot encoded image of dimensions (height x width x num_classes) where num_classes = len(colormap)
    '''
    num_classes = len(colormap)
    shape = rgb_image.shape[:2]+(num_classes,)
    encoded_image = np.zeros( shape, dtype=np.int8 )
    for i, cls in enumerate(colormap):
        encoded_image[:,:,i] = np.all(rgb_image.reshape( (-1,3) ) == colormap[i], axis=1).reshape(shape[:2])
    return encoded_image


def onehot_to_rgb(onehot, colormap = id2code):
    '''Function to decode encoded mask labels
        Inputs: 
            onehot - one hot encoded image matrix (height x width x num_classes)
            colormap - dictionary of color to label id
        Output: Decoded RGB image (height x width x 3) 
    '''
    single_layer = np.argmax(onehot, axis=-1)
    output = np.zeros( onehot.shape[:2]+(3,) )
    for k in colormap.keys():
        output[single_layer==k] = colormap[k]
    return np.uint8(output)

# %% [markdown]
# # Creating custom Image data generators

# %% [markdown]
# ### Defining data generators

# %%
# Normalizing only frame images, since masks contain label info
data_gen_args = dict(rescale=1./255, horizontal_flip=True)
mask_gen_args = dict()

train_frames_datagen = ImageDataGenerator(**data_gen_args)
train_masks_datagen = ImageDataGenerator(**mask_gen_args)
val_frames_datagen = ImageDataGenerator(**data_gen_args)
val_masks_datagen = ImageDataGenerator(**mask_gen_args)

# Seed defined for aligning images and their masks
seed = 1

# %% [markdown]
# ### Custom image data generators for creating batches of frames and masks

# %%
def TrainAugmentGenerator(seed = 1, batch_size = 5):
    '''Train Image data generator
        Inputs: 
            seed - seed provided to the flow_from_directory function to ensure aligned data flow
            batch_size - number of images to import at a time
        Output: Decoded RGB image (height x width x 3) 
    '''
    train_image_generator = train_frames_datagen.flow_from_directory(
    img_dir + 'train_frames/',
    batch_size = batch_size, seed = seed, target_size = (224, 224))

    train_mask_generator = train_masks_datagen.flow_from_directory(
    img_dir + 'train_masks/',
    batch_size = batch_size, seed = seed, target_size = (224, 224))

    while True:
        X1i = train_image_generator.next()
        X2i = train_mask_generator.next()
        
        #One hot encoding RGB images
        mask_encoded = [rgb_to_onehot(X2i[0][x,:,:,:], id2code) for x in range(X2i[0].shape[0])]
        
        yield X1i[0], np.asarray(mask_encoded)

def ValAugmentGenerator(seed = 1, batch_size = 5):
    '''Validation Image data generator
        Inputs: 
            seed - seed provided to the flow_from_directory function to ensure aligned data flow
            batch_size - number of images to import at a time
        Output: Decoded RGB image (height x width x 3) 
    '''
    val_image_generator = val_frames_datagen.flow_from_directory(
    img_dir + 'val_frames/',
    batch_size = batch_size, seed = seed, target_size = (224, 224))


    val_mask_generator = val_masks_datagen.flow_from_directory(
    img_dir + 'val_masks/',
    batch_size = batch_size, seed = seed, target_size = (224, 224))


    while True:
        X1i = val_image_generator.next()
        X2i = val_mask_generator.next()
        
        #One hot encoding RGB images
        mask_encoded = [rgb_to_onehot(X2i[0][x,:,:,:], id2code) for x in range(X2i[0].shape[0])]
        
        yield X1i[0], np.asarray(mask_encoded)

# %%
train = ValAugmentGenerator(batch_size=50)

# %%
next(train)[0].shape
# Out:
# (13, 224, 224, 3)

# %% [markdown]
# # Defining VGG-16 DriuNet model for semantic segmentation
# <b>DriuNet Architecture</b>
#
# <div style="text-align: center;">
#
# ![alt text](https://media.springernature.com/original/springer-static/image/chp%3A10.1007%2F978-3-319-46723-8_17/MediaObjects/432171_1_En_17_Fig1_HTML.gif)
#
# [Picture Credits]https://link.springer.com/chapter/10.1007/978-3-319-46723-8_17)<br><br>

# %%
from tqdm import tqdm

# %%
from tqdm import tqdm_gui

# %% [markdown]
# ### Function to create DriuNet model using VGG-16 pre-trained weights

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *


import os
VGG_Weights_path = "pretrained_weights/vgg16_weights_tf_dim_ordering_tf_kernels.h5"


def driunet_functional(n_classes, input_height=224, input_width=224, input_depth=3):
 
    def concat_block(layers, chanDim=-1):
        # concatenate a group of separate layers
        return concatenate(layers, axis=chanDim)

    def concat_block_output_shape(input_shape):
        input_shape = list(input_shape[0])
        input_shape[1] *= 4
        return tuple(input_shape)

    def conv_block(num_blocks, x, K, kX, kY, 
                   stride=1, chanDim=-1, padding="same", activation = "relu", block_num = 0, BN = False):
        # define a CONV => BN => RELU pattern
        if block_num == 0:
            for i in range(num_blocks):
                x = Conv2D(K, (kX, kY), strides=stride, padding=padding)(x)
                if BN:
                    x = BatchNormalization(axis=chanDim)(x)
                x = Activation(activation)(x)
        else:
            for i in range(num_blocks):
                x = Conv2D(K, (kX, kY), strides=stride, padding=padding, name = "block" + str(block_num) + "_conv" + str(i + 1))(x)
                if BN:
                    x = BatchNormalization(axis=chanDim)(x)(thresh, blackAndWhiteImage)
                x = Activation(activation)(x)
        # return the block
        return x
    
    def upConv_block(x, K, kX, kY, size=1):
        # define a CONV => BN => UPSAMP pattern
        x = conv_block(1, x, K, kX, kY)
        x = UpSampling2D(size=(size, size))(x)
        
        # return the block
        return x

    def specialized_block(block_1, block_2, block_3, block_4, block_5):
        # define five blocks with 16 units extracted from each of the
        # convolutional blocks of the VGGNet so that all outputs are 
        # 224x224.
        convUp_block1 = upConv_block(block_1, 16, 3, 3)
        convUp_block2 = upConv_block(block_2, 16, 3, 3, size=2)
        convUp_block3 = upConv_block(block_3, 16, 3, 3, size=4)
        convUp_block4 = upConv_block(block_4, 16, 3, 3, size=8)
        convUp_block5 = upConv_block(block_5, 16, 3, 3, size=16)

        # Create a lambda function
        lambda_f = Lambda(concat_block, concat_block_output_shape)
        
        # concatenate the upsampled blocks for two outputs
        fine_to_coarse = lambda_f([convUp_block2,
                                   convUp_block3,
                                   convUp_block4,
                                   convUp_block5])
        
        coarse_to_fine = lambda_f([convUp_block4,
                                   convUp_block3,
                                   convUp_block2,
                                   convUp_block1])
        
        # return the blocks
        return fine_to_coarse, coarse_to_fine 
       
    # initialize the input shape to be "channels last" and the
    # channels dimension itself
    inputShape = (input_height, input_width, input_depth)
    chanDim = -1

    # define the model input 
    inputs = Input(shape=inputShape)
 
    # the blocks for create the VGGNet feature extraction 
    conv1 = conv_block(2, inputs, 64, 3, 3, block_num=1)
    pool1 = MaxPooling2D((2,2), strides=(2,2))(conv1)

    conv2 = conv_block(2, pool1, 128, 3, 3, block_num=2)
    pool2 = MaxPooling2D((2,2), strides=(2,2))(conv2)

    conv3 = conv_block(3, pool2, 256, 3, 3, block_num=3)
    pool3 = MaxPooling2D((2,2), strides=(2,2))(conv3)

    conv4 = conv_block(3, pool3, 512, 3, 3, block_num=4)
    pool4 = MaxPooling2D((2,2), strides=(2,2))(conv4)

    conv5 = conv_block(3, pool4, 512, 3, 3, block_num=5)
    pool5 = MaxPooling2D((2,2), strides=(2,2))(conv5)

    baseline = Model(inputs, pool5, name="VGGNet")
    baseline.load_weights(VGG_Weights_path, by_name=True)
    
    # Create the two especialized layers
    FC, CF = specialized_block(conv1, conv2, conv3, conv4, conv5)
 
    # Create the final layers
    FC_conv6 = conv_block(1, FC, n_classes, 3, 3)
    CF_conv6 = conv_block(1, CF, n_classes, 3, 3, 3)

    FC_conv7 = conv_block(1, FC_conv6, 3, 3, 3, activation="sigmoid")
    # CF_conv7 = conv_block(1, CF_conv6, 1, 3, 3, activation="sigmoid")

    # Create the models
    FC_Model = Model(inputs, FC_conv7, name="FC_DRIUNET")
    #CF_Model = Model(inputs, CF_conv7, name="CF_DRIUNET")


    # return the model
    return FC_Model

# %%
#os.getcwd()
#Found 399 images belonging to 1 classes.

# %%
#!wget -O pretrained_weights/vgg16_weights_tf_dim_ordering_tf_kernels.h5  https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5

# %%
DriuNet = driunet_functional(3, input_height=224, input_width=224, input_depth=3)

# %%
DriuNet.summary()
# Out:
# Model: "FC_DRIUNET"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_4[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 224, 224, 64) 0           block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       activation_60[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 224, 224, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 112, 112, 64) 0           activation_61[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 112, 112, 128 0           block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      activation_62[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 112, 112, 128 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 56, 56, 128)  0           activation_63[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 56, 56, 256)  0           block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      activation_64[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 56, 56, 256)  0           block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      activation_65[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 56, 56, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 28, 28, 256)  0           activation_66[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 28, 28, 512)  0           block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     activation_67[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 28, 28, 512)  0           block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     activation_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 28, 28, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 14, 14, 512)  0           activation_69[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 14, 14, 512)  0           block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     activation_70[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 14, 14, 512)  0           block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     activation_71[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 14, 14, 512)  0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 112, 112, 16) 18448       activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 56, 56, 16)   36880       activation_66[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 16)   73744       activation_69[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 16)   73744       activation_72[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 112, 112, 16) 0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 56, 56, 16)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 28, 28, 16)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 14, 14, 16)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_16 (UpSampling2D) (None, 224, 224, 16) 0           activation_74[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_17 (UpSampling2D) (None, 224, 224, 16) 0           activation_75[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_18 (UpSampling2D) (None, 224, 224, 16) 0           activation_76[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_19 (UpSampling2D) (None, 224, 224, 16) 0           activation_77[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 224, 224, 64) 0           up_sampling2d_16[0][0]
#                                                                  up_sampling2d_17[0][0]
#                                                                  up_sampling2d_18[0][0]
#                                                                  up_sampling2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 224, 224, 3)  1731        lambda_3[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 224, 224, 3)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 224, 224, 3)  84          activation_78[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 224, 224, 3)  0           conv2d_28[0][0]
# ==================================================================================================
# Total params: 14,919,319
# Trainable params: 14,919,319
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Defining dice co-efficients for model performance

# %%
# Ref: salehi17, "Twersky loss function for image segmentation using 3D FCDN"
# -> the score is computed for each class separately and then summed
# alpha=beta=0.5 : dice coefficient
# alpha=beta=1   : tanimoto coefficient (also known as jaccard)
# alpha+beta=1   : produces set of F*-scores
# implemented by E. Moebel, 06/04/18
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2,3))
    den = num + alpha*K.sum(p0*g1,(0,1,2,3)) + beta*K.sum(p1*g0,(0,1,2,3))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f*y_true_f) + K.sum(y_pred_f*y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return 1.-dice_coef(y_true, y_pred)

# %%
smooth = 1.

# %% [markdown]
# ## Compiling model
# - Using categorical crossentropy loss since labels have been one hot encoded

# %%
import tensorflow as tf

# %%
DriuNet.summary()
# Out:
# Model: "FC_DRIUNET"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_4[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 224, 224, 64) 0           block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       activation_60[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 224, 224, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 112, 112, 64) 0           activation_61[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 112, 112, 128 0           block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      activation_62[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 112, 112, 128 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 56, 56, 128)  0           activation_63[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 56, 56, 256)  0           block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      activation_64[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 56, 56, 256)  0           block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      activation_65[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 56, 56, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 28, 28, 256)  0           activation_66[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 28, 28, 512)  0           block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     activation_67[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 28, 28, 512)  0           block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     activation_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 28, 28, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 14, 14, 512)  0           activation_69[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 14, 14, 512)  0           block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     activation_70[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 14, 14, 512)  0           block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     activation_71[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 14, 14, 512)  0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 112, 112, 16) 18448       activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 56, 56, 16)   36880       activation_66[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 16)   73744       activation_69[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 16)   73744       activation_72[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 112, 112, 16) 0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 56, 56, 16)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 28, 28, 16)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 14, 14, 16)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_16 (UpSampling2D) (None, 224, 224, 16) 0           activation_74[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_17 (UpSampling2D) (None, 224, 224, 16) 0           activation_75[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_18 (UpSampling2D) (None, 224, 224, 16) 0           activation_76[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_19 (UpSampling2D) (None, 224, 224, 16) 0           activation_77[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 224, 224, 64) 0           up_sampling2d_16[0][0]
#                                                                  up_sampling2d_17[0][0]
#                                                                  up_sampling2d_18[0][0]
#                                                                  up_sampling2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 224, 224, 3)  1731        lambda_3[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 224, 224, 3)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 224, 224, 3)  84          activation_78[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 224, 224, 3)  0           conv2d_28[0][0]
# ==================================================================================================
# Total params: 14,919,319
# Trainable params: 14,919,319
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
adam = tf.keras.optimizers.Adam(learning_rate=1e-5)
DriuNet.compile(optimizer=adam, loss="categorical_crossentropy", metrics=[tversky_loss,dice_coef])

# %%
#model.load_weights("model_100_epochs.h5")

# %% [markdown]
# ## Define model callback settings

# %%
tb = TensorBoard(log_dir='logs', write_graph=True)
mc = ModelCheckpoint(mode='max', filepath='weedmap_model_vgg16_driunet_checkpoint_1.h5', monitor='val_dice_coef', save_best_only='True', save_weights_only='True', verbose=1)
es = EarlyStopping(mode='min', monitor='val_loss', patience=50, verbose=1)
callbacks = [tb, mc, es](Ortho) RedEdge 5 channel multispectral images

# %% [markdown]
# ## Train and save the SegNet model

# %%
batch_size = 32
steps_per_epoch = np.ceil(float(len(train_frames_list) - round(0.2*len(train_frames_list))) / float(batch_size))
steps_per_epoch
# Out:
# 20.0

# %%
validation_steps = np.floor((float((round(0.2*len(train_frames_list)))) / float(batch_size)))
validation_steps
# Out:
# 4.0

# %%
TrainAugmentGenerator().next()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-1c3e87e4a499> in <module>
# ----> 1 TrainAugmentGenerator().next()
#
# AttributeError: 'generator' object has no attribute 'next'

# %%
num_epochs = 300

# %%
# Train model
result = DriuNet.fit_generator(TrainAugmentGenerator(), steps_per_epoch=steps_per_epoch,
                validation_data = ValAugmentGenerator(), 
                validation_steps = 4, epochs=300, callbacks=callbacks, verbose=1)
DriuNet.save_weights("weedmap_model_vgg16_driunet_1.h5", overwrite=True)
# Out:
# Found 336 images belonging to 1 classes.
# Epoch 1/300
# Found 336 images belonging to 1 classes.
# 19/20 [===========================>..] - ETA: 0s - loss: 0.8600 - tversky_loss: 2.4418 - dice_coef: 0.6284Found 63 images belonging to 1 classes.
# Found 63 images belonging to 1 classes.
#
# Epoch 00001: val_dice_coef improved from -inf to 0.74904, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 223ms/step - loss: 0.8484 - tversky_loss: 2.4351 - dice_coef: 0.6348 - val_loss: 0.6343 - val_tversky_loss: 2.3104 - val_dice_coef: 0.7490
# Epoch 2/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5916 - tversky_loss: 2.2903 - dice_coef: 0.7833
# Epoch 00002: val_dice_coef improved from 0.74904 to 0.79199, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 198ms/step - loss: 0.5906 - tversky_loss: 2.2909 - dice_coef: 0.7837 - val_loss: 0.5843 - val_tversky_loss: 2.3014 - val_dice_coef: 0.7920
# Epoch 3/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5348 - tversky_loss: 2.2781 - dice_coef: 0.8123
# Epoch 00003: val_dice_coef improved from 0.79199 to 0.80796, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 199ms/step - loss: 0.5415 - tversky_loss: 2.2802 - dice_coef: 0.8099 - val_loss: 0.5538 - val_tversky_loss: 2.2777 - val_dice_coef: 0.8080
# Epoch 4/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5535 - tversky_loss: 2.2888 - dice_coef: 0.8055
# Epoch 00004: val_dice_coef improved from 0.80796 to 0.80899, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 208ms/step - loss: 0.5505 - tversky_loss: 2.2880 - dice_coef: 0.8060 - val_loss: 0.5370 - val_tversky_loss: 2.2766 - val_dice_coef: 0.8090
# Epoch 5/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5311 - tversky_loss: 2.2755 - dice_coef: 0.8149
# Epoch 00005: val_dice_coef did not improve from 0.80899
# 20/20 [==============================] - 4s 197ms/step - loss: 0.5298 - tversky_loss: 2.2757 - dice_coef: 0.8150 - val_loss: 0.5483 - val_tversky_loss: 2.2838 - val_dice_coef: 0.8085
# Epoch 6/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5278 - tversky_loss: 2.2725 - dice_coef: 0.8191
# Epoch 00006: val_dice_coef did not improve from 0.80899
# 20/20 [==============================] - 4s 194ms/step - loss: 0.5277 - tversky_loss: 2.2737 - dice_coef: 0.8182 - val_loss: 0.5495 - val_tversky_loss: 2.2811 - val_dice_coef: 0.8080
# Epoch 7/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5038 - tversky_loss: 2.2649 - dice_coef: 0.8244
# Epoch 00007: val_dice_coef improved from 0.80899 to 0.83282, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 213ms/step - loss: 0.5059 - tversky_loss: 2.2654 - dice_coef: 0.8238 - val_loss: 0.4820 - val_tversky_loss: 2.2502 - val_dice_coef: 0.8328
# Epoch 8/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5215 - tversky_loss: 2.2743 - dice_coef: 0.8163
# Epoch 00008: val_dice_coef did not improve from 0.83282
# 20/20 [==============================] - 4s 191ms/step - loss: 0.5238 - tversky_loss: 2.2754 - dice_coef: 0.8157 - val_loss: 0.5196 - val_tversky_loss: 2.2677 - val_dice_coef: 0.8209
# Epoch 9/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5000 - tversky_loss: 2.2656 - dice_coef: 0.8251
# Epoch 00009: val_dice_coef did not improve from 0.83282
# 20/20 [==============================] - 4s 191ms/step - loss: 0.5020 - tversky_loss: 2.2663 - dice_coef: 0.8245 - val_loss: 0.4906 - val_tversky_loss: 2.2575 - val_dice_coef: 0.8324
# Epoch 10/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5049 - tversky_loss: 2.2681 - dice_coef: 0.8224
# Epoch 00010: val_dice_coef did not improve from 0.83282
# 20/20 [==============================] - 4s 194ms/step - loss: 0.5062 - tversky_loss: 2.2682 - dice_coef: 0.8223 - val_loss: 0.5103 - val_tversky_loss: 2.2621 - val_dice_coef: 0.8240
# Epoch 11/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5109 - tversky_loss: 2.2676 - dice_coef: 0.8239
# Epoch 00011: val_dice_coef did not improve from 0.83282
# 20/20 [==============================] - 4s 187ms/step - loss: 0.5085 - tversky_loss: 2.2662 - dice_coef: 0.8249 - val_loss: 0.5307 - val_tversky_loss: 2.2718 - val_dice_coef: 0.8178
# Epoch 12/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5067 - tversky_loss: 2.2652 - dice_coef: 0.8247
# Epoch 00012: val_dice_coef did not improve from 0.83282
# 20/20 [==============================] - 4s 193ms/step - loss: 0.5077 - tversky_loss: 2.2656 - dice_coef: 0.8247 - val_loss: 0.4903 - val_tversky_loss: 2.2590 - val_dice_coef: 0.8322
# Epoch 13/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5119 - tversky_loss: 2.2685 - dice_coef: 0.8248
# Epoch 00013: val_dice_coef did not improve from 0.83282
# 20/20 [==============================] - 4s 189ms/step - loss: 0.5116 - tversky_loss: 2.2682 - dice_coef: 0.8249 - val_loss: 0.4953 - val_tversky_loss: 2.2611 - val_dice_coef: 0.8299
# Epoch 14/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5036 - tversky_loss: 2.2706 - dice_coef: 0.8195
# Epoch 00014: val_dice_coef did not improve from 0.83282
# 20/20 [==============================] - 4s 190ms/step - loss: 0.5083 - tversky_loss: 2.2715 - dice_coef: 0.8188 - val_loss: 0.5392 - val_tversky_loss: 2.2711 - val_dice_coef: 0.8204
# Epoch 15/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4917 - tversky_loss: 2.2595 - dice_coef: 0.8313
# Epoch 00015: val_dice_coef did not improve from 0.83282
# 20/20 [==============================] - 4s 191ms/step - loss: 0.4913 - tversky_loss: 2.2589 - dice_coef: 0.8319 - val_loss: 0.4793 - val_tversky_loss: 2.2589 - val_dice_coef: 0.8293
# Epoch 16/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4898 - tversky_loss: 2.2560 - dice_coef: 0.8331
# Epoch 00016: val_dice_coef improved from 0.83282 to 0.83887, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 210ms/step - loss: 0.4889 - tversky_loss: 2.2555 - dice_coef: 0.8337 - val_loss: 0.4692 - val_tversky_loss: 2.2496 - val_dice_coef: 0.8389
# Epoch 17/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4989 - tversky_loss: 2.2644 - dice_coef: 0.8278
# Epoch 00017: val_dice_coef did not improve from 0.83887
# 20/20 [==============================] - 4s 186ms/step - loss: 0.4964 - tversky_loss: 2.2629 - dice_coef: 0.8292 - val_loss: 0.5279 - val_tversky_loss: 2.2737 - val_dice_coef: 0.8182
# Epoch 18/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4904 - tversky_loss: 2.2595 - dice_coef: 0.8310
# Epoch 00018: val_dice_coef did not improve from 0.83887
# 20/20 [==============================] - 4s 191ms/step - loss: 0.4913 - tversky_loss: 2.2594 - dice_coef: 0.8311 - val_loss: 0.5045 - val_tversky_loss: 2.2573 - val_dice_coef: 0.8303
# Epoch 19/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4979 - tversky_loss: 2.2599 - dice_coef: 0.8311
# Epoch 00019: val_dice_coef did not improve from 0.83887
# 20/20 [==============================] - 4s 190ms/step - loss: 0.4990 - tversky_loss: 2.2609 - dice_coef: 0.8302 - val_loss: 0.4834 - val_tversky_loss: 2.2513 - val_dice_coef: 0.8384
# Epoch 20/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.5000 - tversky_loss: 2.2624 - dice_coef: 0.8281
# Epoch 00020: val_dice_coef did not improve from 0.83887
# 20/20 [==============================] - 4s 191ms/step - loss: 0.4962 - tversky_loss: 2.2607 - dice_coef: 0.8299 - val_loss: 0.4948 - val_tversky_loss: 2.2593 - val_dice_coef: 0.8303
# Epoch 21/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4975 - tversky_loss: 2.2594 - dice_coef: 0.8326
# Epoch 00021: val_dice_coef did not improve from 0.83887
# 20/20 [==============================] - 4s 185ms/step - loss: 0.4955 - tversky_loss: 2.2580 - dice_coef: 0.8337 - val_loss: 0.4941 - val_tversky_loss: 2.2498 - val_dice_coef: 0.8363
# Epoch 22/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4787 - tversky_loss: 2.2552 - dice_coef: 0.8348
# Epoch 00022: val_dice_coef did not improve from 0.83887
# 20/20 [==============================] - 4s 185ms/step - loss: 0.4812 - tversky_loss: 2.2560 - dice_coef: 0.8340 - val_loss: 0.4953 - val_tversky_loss: 2.2575 - val_dice_coef: 0.8321
# Epoch 23/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4759 - tversky_loss: 2.2526 - dice_coef: 0.8380
# Epoch 00023: val_dice_coef improved from 0.83887 to 0.84255, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 202ms/step - loss: 0.4738 - tversky_loss: 2.2520 - dice_coef: 0.8385 - val_loss: 0.4573 - val_tversky_loss: 2.2433 - val_dice_coef: 0.8426
# Epoch 24/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4619 - tversky_loss: 2.2430 - dice_coef: 0.8458
# Epoch 00024: val_dice_coef improved from 0.84255 to 0.84350, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 198ms/step - loss: 0.4644 - tversky_loss: 2.2441 - dice_coef: 0.8448 - val_loss: 0.4468 - val_tversky_loss: 2.2427 - val_dice_coef: 0.8435
# Epoch 25/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4609 - tversky_loss: 2.2456 - dice_coef: 0.8427
# Epoch 00025: val_dice_coef improved from 0.84350 to 0.86673, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 203ms/step - loss: 0.4619 - tversky_loss: 2.2456 - dice_coef: 0.8429 - val_loss: 0.4164 - val_tversky_loss: 2.2190 - val_dice_coef: 0.8667
# Epoch 26/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4703 - tversky_loss: 2.2489 - dice_coef: 0.8403
# Epoch 00026: val_dice_coef did not improve from 0.86673
# 20/20 [==============================] - 4s 183ms/step - loss: 0.4704 - tversky_loss: 2.2486 - dice_coef: 0.8408 - val_loss: 0.4833 - val_tversky_loss: 2.2575 - val_dice_coef: 0.8365
# Epoch 27/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4684 - tversky_loss: 2.2449 - dice_coef: 0.8454
# Epoch 00027: val_dice_coef did not improve from 0.86673
# 20/20 [==============================] - 4s 181ms/step - loss: 0.4689 - tversky_loss: 2.2463 - dice_coef: 0.8439 - val_loss: 0.4405 - val_tversky_loss: 2.2281 - val_dice_coef: 0.8557
# Epoch 28/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4673 - tversky_loss: 2.2448 - dice_coef: 0.8446
# Epoch 00028: val_dice_coef did not improve from 0.86673
# 20/20 [==============================] - 4s 180ms/step - loss: 0.4691 - tversky_loss: 2.2455 - dice_coef: 0.8438 - val_loss: 0.4439 - val_tversky_loss: 2.2202 - val_dice_coef: 0.8640
# Epoch 29/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4444 - tversky_loss: 2.2374 - dice_coef: 0.8494
# Epoch 00029: val_dice_coef did not improve from 0.86673
# 20/20 [==============================] - 4s 181ms/step - loss: 0.4447 - tversky_loss: 2.2377 - dice_coef: 0.8494 - val_loss: 0.4523 - val_tversky_loss: 2.2301 - val_dice_coef: 0.8556
# Epoch 30/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4495 - tversky_loss: 2.2317 - dice_coef: 0.8554
# Epoch 00030: val_dice_coef improved from 0.86673 to 0.88490, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 205ms/step - loss: 0.4492 - tversky_loss: 2.2297 - dice_coef: 0.8566 - val_loss: 0.3475 - val_tversky_loss: 2.1863 - val_dice_coef: 0.8849
# Epoch 31/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3783 - tversky_loss: 2.1788 - dice_coef: 0.8831
# Epoch 00031: val_dice_coef improved from 0.88490 to 0.88694, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 197ms/step - loss: 0.3791 - tversky_loss: 2.1805 - dice_coef: 0.8817 - val_loss: 0.3370 - val_tversky_loss: 2.1617 - val_dice_coef: 0.8869
# Epoch 32/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.4112 - tversky_loss: 2.2051 - dice_coef: 0.8638
# Epoch 00032: val_dice_coef did not improve from 0.88694
# 20/20 [==============================] - 4s 183ms/step - loss: 0.4159 - tversky_loss: 2.2052 - dice_coef: 0.8636 - val_loss: 0.3782 - val_tversky_loss: 2.1952 - val_dice_coef: 0.8725
# Epoch 33/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3369 - tversky_loss: 2.1750 - dice_coef: 0.8855
# Epoch 00033: val_dice_coef did not improve from 0.88694
# 20/20 [==============================] - 4s 183ms/step - loss: 0.3316 - tversky_loss: 2.1729 - dice_coef: 0.8866 - val_loss: 0.3795 - val_tversky_loss: 2.1714 - val_dice_coef: 0.8796
# Epoch 34/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3681 - tversky_loss: 2.1900 - dice_coef: 0.8746
# Epoch 00034: val_dice_coef did not improve from 0.88694
# 20/20 [==============================] - 4s 181ms/step - loss: 0.3518 - tversky_loss: 2.1814 - dice_coef: 0.8803 - val_loss: 0.4370 - val_tversky_loss: 2.1857 - val_dice_coef: 0.8710
# Epoch 35/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3620 - tversky_loss: 2.1922 - dice_coef: 0.8706
# Epoch 00035: val_dice_coef improved from 0.88694 to 0.91930, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 202ms/step - loss: 0.3643 - tversky_loss: 2.1938 - dice_coef: 0.8689 - val_loss: 0.2486 - val_tversky_loss: 2.1197 - val_dice_coef: 0.9193
# Epoch 36/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3539 - tversky_loss: 2.1784 - dice_coef: 0.8833
# Epoch 00036: val_dice_coef did not improve from 0.91930
# 20/20 [==============================] - 4s 186ms/step - loss: 0.3500 - tversky_loss: 2.1754 - dice_coef: 0.8856 - val_loss: 0.3803 - val_tversky_loss: 2.1724 - val_dice_coef: 0.8847
# Epoch 37/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3330 - tversky_loss: 2.1676 - dice_coef: 0.8891
# Epoch 00037: val_dice_coef did not improve from 0.91930
# 20/20 [==============================] - 4s 183ms/step - loss: 0.3285 - tversky_loss: 2.1670 - dice_coef: 0.8896 - val_loss: 0.3893 - val_tversky_loss: 2.2015 - val_dice_coef: 0.8675
# Epoch 38/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3134 - tversky_loss: 2.1637 - dice_coef: 0.8901
# Epoch 00038: val_dice_coef did not improve from 0.91930
# 20/20 [==============================] - 4s 179ms/step - loss: 0.3142 - tversky_loss: 2.1646 - dice_coef: 0.8901 - val_loss: 0.2652 - val_tversky_loss: 2.1216 - val_dice_coef: 0.9177
# Epoch 39/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3314 - tversky_loss: 2.1769 - dice_coef: 0.8831
# Epoch 00039: val_dice_coef did not improve from 0.91930
# 20/20 [==============================] - 4s 183ms/step - loss: 0.3309 - tversky_loss: 2.1762 - dice_coef: 0.8834 - val_loss: 0.3662 - val_tversky_loss: 2.1946 - val_dice_coef: 0.8697
# Epoch 40/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3239 - tversky_loss: 2.1714 - dice_coef: 0.8828
# Epoch 00040: val_dice_coef did not improve from 0.91930
# 20/20 [==============================] - 4s 186ms/step - loss: 0.3193 - tversky_loss: 2.1686 - dice_coef: 0.8851 - val_loss: 0.2925 - val_tversky_loss: 2.1592 - val_dice_coef: 0.8951
# Epoch 41/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3083 - tversky_loss: 2.1622 - dice_coef: 0.8901
# Epoch 00041: val_dice_coef did not improve from 0.91930
# 20/20 [==============================] - 4s 184ms/step - loss: 0.3195 - tversky_loss: 2.1673 - dice_coef: 0.8865 - val_loss: 0.3395 - val_tversky_loss: 2.1331 - val_dice_coef: 0.9088
# Epoch 42/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2902 - tversky_loss: 2.1610 - dice_coef: 0.8914
# Epoch 00042: val_dice_coef did not improve from 0.91930
# 20/20 [==============================] - 4s 185ms/step - loss: 0.2970 - tversky_loss: 2.1602 - dice_coef: 0.8919 - val_loss: 0.2906 - val_tversky_loss: 2.1436 - val_dice_coef: 0.8954
# Epoch 43/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3231 - tversky_loss: 2.1673 - dice_coef: 0.8888
# Epoch 00043: val_dice_coef did not improve from 0.91930
# 20/20 [==============================] - 4s 183ms/step - loss: 0.3225 - tversky_loss: 2.1656 - dice_coef: 0.8898 - val_loss: 0.3441 - val_tversky_loss: 2.1603 - val_dice_coef: 0.8906
# Epoch 44/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3112 - tversky_loss: 2.1575 - dice_coef: 0.8932
# Epoch 00044: val_dice_coef did not improve from 0.91930
# 20/20 [==============================] - 4s 182ms/step - loss: 0.3103 - tversky_loss: 2.1579 - dice_coef: 0.8934 - val_loss: 0.3686 - val_tversky_loss: 2.1749 - val_dice_coef: 0.8833
# Epoch 45/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2754 - tversky_loss: 2.1409 - dice_coef: 0.9061
# Epoch 00045: val_dice_coef did not improve from 0.91930
# 20/20 [==============================] - 4s 181ms/step - loss: 0.2707 - tversky_loss: 2.1381 - dice_coef: 0.9082 - val_loss: 0.3914 - val_tversky_loss: 2.1945 - val_dice_coef: 0.8721
# Epoch 46/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3104 - tversky_loss: 2.1683 - dice_coef: 0.8855
# Epoch 00046: val_dice_coef did not improve from 0.91930
# 20/20 [==============================] - 4s 183ms/step - loss: 0.3121 - tversky_loss: 2.1702 - dice_coef: 0.8840 - val_loss: 0.3171 - val_tversky_loss: 2.1624 - val_dice_coef: 0.8849
# Epoch 47/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2865 - tversky_loss: 2.1534 - dice_coef: 0.8949
# Epoch 00047: val_dice_coef improved from 0.91930 to 0.92685, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 207ms/step - loss: 0.2948 - tversky_loss: 2.1563 - dice_coef: 0.8931 - val_loss: 0.1995 - val_tversky_loss: 2.1063 - val_dice_coef: 0.9269
# Epoch 48/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3110 - tversky_loss: 2.1508 - dice_coef: 0.8984
# Epoch 00048: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 180ms/step - loss: 0.3099 - tversky_loss: 2.1518 - dice_coef: 0.8976 - val_loss: 0.2933 - val_tversky_loss: 2.1142 - val_dice_coef: 0.9230
# Epoch 49/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2987 - tversky_loss: 2.1560 - dice_coef: 0.8939
# Epoch 00049: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 183ms/step - loss: 0.3055 - tversky_loss: 2.1592 - dice_coef: 0.8925 - val_loss: 0.3009 - val_tversky_loss: 2.1587 - val_dice_coef: 0.8975
# Epoch 50/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2897 - tversky_loss: 2.1535 - dice_coef: 0.8980
# Epoch 00050: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 184ms/step - loss: 0.2923 - tversky_loss: 2.1548 - dice_coef: 0.8968 - val_loss: 0.3404 - val_tversky_loss: 2.1599 - val_dice_coef: 0.8905
# Epoch 51/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3229 - tversky_loss: 2.1738 - dice_coef: 0.8820
# Epoch 00051: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 180ms/step - loss: 0.3197 - tversky_loss: 2.1736 - dice_coef: 0.8816 - val_loss: 0.3853 - val_tversky_loss: 2.1689 - val_dice_coef: 0.8796
# Epoch 52/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3004 - tversky_loss: 2.1652 - dice_coef: 0.8890
# Epoch 00052: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 185ms/step - loss: 0.2923 - tversky_loss: 2.1615 - dice_coef: 0.8913 - val_loss: 0.2560 - val_tversky_loss: 2.1395 - val_dice_coef: 0.9015
# Epoch 53/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3012 - tversky_loss: 2.1615 - dice_coef: 0.8909
# Epoch 00053: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 187ms/step - loss: 0.3006 - tversky_loss: 2.1622 - dice_coef: 0.8902 - val_loss: 0.2224 - val_tversky_loss: 2.1166 - val_dice_coef: 0.9198
# Epoch 54/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2848 - tversky_loss: 2.1422 - dice_coef: 0.9048
# Epoch 00054: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 183ms/step - loss: 0.2894 - tversky_loss: 2.1451 - dice_coef: 0.9027 - val_loss: 0.3421 - val_tversky_loss: 2.1647 - val_dice_coef: 0.8827
# Epoch 55/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2998 - tversky_loss: 2.1418 - dice_coef: 0.9029
# Epoch 00055: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 178ms/step - loss: 0.3058 - tversky_loss: 2.1448 - dice_coef: 0.9012 - val_loss: 0.3379 - val_tversky_loss: 2.1559 - val_dice_coef: 0.9017
# Epoch 56/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3163 - tversky_loss: 2.1673 - dice_coef: 0.8881
# Epoch 00056: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 183ms/step - loss: 0.3150 - tversky_loss: 2.1670 - dice_coef: 0.8888 - val_loss: 0.3440 - val_tversky_loss: 2.1587 - val_dice_coef: 0.8921
# Epoch 57/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3166 - tversky_loss: 2.1641 - dice_coef: 0.8912
# Epoch 00057: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 184ms/step - loss: 0.3156 - tversky_loss: 2.1634 - dice_coef: 0.8921 - val_loss: 0.2377 - val_tversky_loss: 2.1375 - val_dice_coef: 0.9079
# Epoch 58/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2855 - tversky_loss: 2.1427 - dice_coef: 0.9049
# Epoch 00058: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 176ms/step - loss: 0.2921 - tversky_loss: 2.1469 - dice_coef: 0.9022 - val_loss: 0.3523 - val_tversky_loss: 2.1779 - val_dice_coef: 0.8785
# Epoch 59/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2815 - tversky_loss: 2.1453 - dice_coef: 0.9032
# Epoch 00059: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 182ms/step - loss: 0.2909 - tversky_loss: 2.1484 - dice_coef: 0.9010 - val_loss: 0.3266 - val_tversky_loss: 2.1283 - val_dice_coef: 0.9139
# Epoch 60/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2783 - tversky_loss: 2.1500 - dice_coef: 0.8977
# Epoch 00060: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 184ms/step - loss: 0.2834 - tversky_loss: 2.1512 - dice_coef: 0.8970 - val_loss: 0.3202 - val_tversky_loss: 2.1724 - val_dice_coef: 0.8789
# Epoch 61/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3097 - tversky_loss: 2.1660 - dice_coef: 0.8883
# Epoch 00061: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 184ms/step - loss: 0.3071 - tversky_loss: 2.1657 - dice_coef: 0.8882 - val_loss: 0.3273 - val_tversky_loss: 2.1511 - val_dice_coef: 0.8960
# Epoch 62/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2288 - tversky_loss: 2.1162 - dice_coef: 0.9211
# Epoch 00062: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 179ms/step - loss: 0.2235 - tversky_loss: 2.1145 - dice_coef: 0.9224 - val_loss: 0.3190 - val_tversky_loss: 2.1501 - val_dice_coef: 0.8998
# Epoch 63/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3165 - tversky_loss: 2.1731 - dice_coef: 0.8838
# Epoch 00063: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 183ms/step - loss: 0.3109 - tversky_loss: 2.1699 - dice_coef: 0.8858 - val_loss: 0.3020 - val_tversky_loss: 2.1410 - val_dice_coef: 0.9072
# Epoch 64/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2738 - tversky_loss: 2.1482 - dice_coef: 0.8982
# Epoch 00064: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 183ms/step - loss: 0.2714 - tversky_loss: 2.1470 - dice_coef: 0.8993 - val_loss: 0.2541 - val_tversky_loss: 2.1226 - val_dice_coef: 0.9194
# Epoch 65/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.3143 - tversky_loss: 2.1583 - dice_coef: 0.8948
# Epoch 00065: val_dice_coef did not improve from 0.92685
# 20/20 [==============================] - 4s 182ms/step - loss: 0.3065 - tversky_loss: 2.1547 - dice_coef: 0.8973 - val_loss: 0.3171 - val_tversky_loss: 2.1540 - val_dice_coef: 0.8984
# Epoch 66/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2523 - tversky_loss: 2.1365 - dice_coef: 0.9087
# Epoch 00066: val_dice_coef improved from 0.92685 to 0.92851, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 207ms/step - loss: 0.2571 - tversky_loss: 2.1390 - dice_coef: 0.9068 - val_loss: 0.2715 - val_tversky_loss: 2.1015 - val_dice_coef: 0.9285
# Epoch 67/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2988 - tversky_loss: 2.1624 - dice_coef: 0.8899
# Epoch 00067: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 185ms/step - loss: 0.2945 - tversky_loss: 2.1595 - dice_coef: 0.8916 - val_loss: 0.2785 - val_tversky_loss: 2.1189 - val_dice_coef: 0.9166
# Epoch 68/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2606 - tversky_loss: 2.1394 - dice_coef: 0.9046
# Epoch 00068: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 178ms/step - loss: 0.2771 - tversky_loss: 2.1434 - dice_coef: 0.9025 - val_loss: 0.3017 - val_tversky_loss: 2.1361 - val_dice_coef: 0.9126
# Epoch 69/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2314 - tversky_loss: 2.1193 - dice_coef: 0.9199
# Epoch 00069: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 181ms/step - loss: 0.2402 - tversky_loss: 2.1239 - dice_coef: 0.9167 - val_loss: 0.2101 - val_tversky_loss: 2.1079 - val_dice_coef: 0.9234
# Epoch 70/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2964 - tversky_loss: 2.1496 - dice_coef: 0.8996
# Epoch 00070: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 182ms/step - loss: 0.2949 - tversky_loss: 2.1497 - dice_coef: 0.8992 - val_loss: 0.3154 - val_tversky_loss: 2.1535 - val_dice_coef: 0.8967
# Epoch 71/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2888 - tversky_loss: 2.1611 - dice_coef: 0.8907
# Epoch 00071: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 183ms/step - loss: 0.2831 - tversky_loss: 2.1586 - dice_coef: 0.8921 - val_loss: 0.2347 - val_tversky_loss: 2.1325 - val_dice_coef: 0.9084
# Epoch 72/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2539 - tversky_loss: 2.1322 - dice_coef: 0.9109
# Epoch 00072: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 178ms/step - loss: 0.2600 - tversky_loss: 2.1361 - dice_coef: 0.9079 - val_loss: 0.2599 - val_tversky_loss: 2.1437 - val_dice_coef: 0.9028
# Epoch 73/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2920 - tversky_loss: 2.1509 - dice_coef: 0.8996
# Epoch 00073: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 184ms/step - loss: 0.2972 - tversky_loss: 2.1537 - dice_coef: 0.8971 - val_loss: 0.3141 - val_tversky_loss: 2.1411 - val_dice_coef: 0.9060
# Epoch 74/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2509 - tversky_loss: 2.1349 - dice_coef: 0.9077
# Epoch 00074: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 185ms/step - loss: 0.2548 - tversky_loss: 2.1375 - dice_coef: 0.9062 - val_loss: 0.2741 - val_tversky_loss: 2.1430 - val_dice_coef: 0.9049
# Epoch 75/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2749 - tversky_loss: 2.1439 - dice_coef: 0.9026
# Epoch 00075: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 179ms/step - loss: 0.2717 - tversky_loss: 2.1436 - dice_coef: 0.9028 - val_loss: 0.2632 - val_tversky_loss: 2.1329 - val_dice_coef: 0.9140
# Epoch 76/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2331 - tversky_loss: 2.1351 - dice_coef: 0.9073
# Epoch 00076: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 184ms/step - loss: 0.2390 - tversky_loss: 2.1376 - dice_coef: 0.9059 - val_loss: 0.3008 - val_tversky_loss: 2.1513 - val_dice_coef: 0.8946
# Epoch 77/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2811 - tversky_loss: 2.1442 - dice_coef: 0.9008
# Epoch 00077: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 185ms/step - loss: 0.2875 - tversky_loss: 2.1476 - dice_coef: 0.8981 - val_loss: 0.2734 - val_tversky_loss: 2.1449 - val_dice_coef: 0.9006
# Epoch 78/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2706 - tversky_loss: 2.1381 - dice_coef: 0.9071
# Epoch 00078: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 182ms/step - loss: 0.2669 - tversky_loss: 2.1366 - dice_coef: 0.9077 - val_loss: 0.2287 - val_tversky_loss: 2.1197 - val_dice_coef: 0.9209
# Epoch 79/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2510 - tversky_loss: 2.1387 - dice_coef: 0.9069
# Epoch 00079: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 179ms/step - loss: 0.2567 - tversky_loss: 2.1414 - dice_coef: 0.9046 - val_loss: 0.2871 - val_tversky_loss: 2.1271 - val_dice_coef: 0.9104
# Epoch 80/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2759 - tversky_loss: 2.1482 - dice_coef: 0.9019
# Epoch 00080: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 181ms/step - loss: 0.2725 - tversky_loss: 2.1457 - dice_coef: 0.9032 - val_loss: 0.2631 - val_tversky_loss: 2.1381 - val_dice_coef: 0.9030
# Epoch 81/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2509 - tversky_loss: 2.1331 - dice_coef: 0.9086
# Epoch 00081: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 185ms/step - loss: 0.2475 - tversky_loss: 2.1318 - dice_coef: 0.9095 - val_loss: 0.2949 - val_tversky_loss: 2.1346 - val_dice_coef: 0.9123
# Epoch 82/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2410 - tversky_loss: 2.1341 - dice_coef: 0.9093
# Epoch 00082: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 184ms/step - loss: 0.2394 - tversky_loss: 2.1332 - dice_coef: 0.9097 - val_loss: 0.3037 - val_tversky_loss: 2.1449 - val_dice_coef: 0.9023
# Epoch 83/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2820 - tversky_loss: 2.1506 - dice_coef: 0.8992
# Epoch 00083: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 187ms/step - loss: 0.2816 - tversky_loss: 2.1510 - dice_coef: 0.8986 - val_loss: 0.2404 - val_tversky_loss: 2.1279 - val_dice_coef: 0.9174
# Epoch 84/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2617 - tversky_loss: 2.1388 - dice_coef: 0.9073
# Epoch 00084: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 185ms/step - loss: 0.2694 - tversky_loss: 2.1403 - dice_coef: 0.9062 - val_loss: 0.2819 - val_tversky_loss: 2.1438 - val_dice_coef: 0.9016
# Epoch 85/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2576 - tversky_loss: 2.1333 - dice_coef: 0.9097
# Epoch 00085: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 179ms/step - loss: 0.2555 - tversky_loss: 2.1342 - dice_coef: 0.9091 - val_loss: 0.3511 - val_tversky_loss: 2.1642 - val_dice_coef: 0.8934
# Epoch 86/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2589 - tversky_loss: 2.1386 - dice_coef: 0.9076
# Epoch 00086: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 183ms/step - loss: 0.2623 - tversky_loss: 2.1391 - dice_coef: 0.9074 - val_loss: 0.2262 - val_tversky_loss: 2.1170 - val_dice_coef: 0.9186
# Epoch 87/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2212 - tversky_loss: 2.1234 - dice_coef: 0.9158
# Epoch 00087: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 187ms/step - loss: 0.2191 - tversky_loss: 2.1211 - dice_coef: 0.9177 - val_loss: 0.2510 - val_tversky_loss: 2.1265 - val_dice_coef: 0.9143
# Epoch 88/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2954 - tversky_loss: 2.1563 - dice_coef: 0.8941
# Epoch 00088: val_dice_coef did not improve from 0.92851
# 20/20 [==============================] - 4s 185ms/step - loss: 0.2920 - tversky_loss: 2.1546 - dice_coef: 0.8952 - val_loss: 0.2620 - val_tversky_loss: 2.1401 - val_dice_coef: 0.9080
# Epoch 89/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2397 - tversky_loss: 2.1269 - dice_coef: 0.9161
# Epoch 00089: val_dice_coef improved from 0.92851 to 0.93462, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 201ms/step - loss: 0.2435 - tversky_loss: 2.1277 - dice_coef: 0.9153 - val_loss: 0.1962 - val_tversky_loss: 2.1021 - val_dice_coef: 0.9346
# Epoch 90/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2491 - tversky_loss: 2.1384 - dice_coef: 0.9081
# Epoch 00090: val_dice_coef did not improve from 0.93462
# 20/20 [==============================] - 4s 183ms/step - loss: 0.2542 - tversky_loss: 2.1391 - dice_coef: 0.9076 - val_loss: 0.3223 - val_tversky_loss: 2.1562 - val_dice_coef: 0.8915
# Epoch 91/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2708 - tversky_loss: 2.1483 - dice_coef: 0.8991
# Epoch 00091: val_dice_coef did not improve from 0.93462
# 20/20 [==============================] - 4s 182ms/step - loss: 0.2773 - tversky_loss: 2.1503 - dice_coef: 0.8982 - val_loss: 0.2521 - val_tversky_loss: 2.1317 - val_dice_coef: 0.9102
# Epoch 92/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2328 - tversky_loss: 2.1242 - dice_coef: 0.9149
# Epoch 00092: val_dice_coef did not improve from 0.93462
# 20/20 [==============================] - 4s 178ms/step - loss: 0.2372 - tversky_loss: 2.1247 - dice_coef: 0.9142 - val_loss: 0.2279 - val_tversky_loss: 2.1094 - val_dice_coef: 0.9282
# Epoch 93/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2337 - tversky_loss: 2.1294 - dice_coef: 0.9126
# Epoch 00093: val_dice_coef did not improve from 0.93462
# 20/20 [==============================] - 4s 181ms/step - loss: 0.2387 - tversky_loss: 2.1305 - dice_coef: 0.9121 - val_loss: 0.2905 - val_tversky_loss: 2.1339 - val_dice_coef: 0.9067
# Epoch 94/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2345 - tversky_loss: 2.1308 - dice_coef: 0.9091
# Epoch 00094: val_dice_coef did not improve from 0.93462
# 20/20 [==============================] - 4s 182ms/step - loss: 0.2369 - tversky_loss: 2.1326 - dice_coef: 0.9082 - val_loss: 0.3132 - val_tversky_loss: 2.1460 - val_dice_coef: 0.9060
# Epoch 95/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2525 - tversky_loss: 2.1380 - dice_coef: 0.9064
# Epoch 00095: val_dice_coef did not improve from 0.93462
# 20/20 [==============================] - 4s 183ms/step - loss: 0.2514 - tversky_loss: 2.1369 - dice_coef: 0.9071 - val_loss: 0.2944 - val_tversky_loss: 2.1473 - val_dice_coef: 0.9037
# Epoch 96/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2015 - tversky_loss: 2.1132 - dice_coef: 0.9231
# Epoch 00096: val_dice_coef did not improve from 0.93462
# 20/20 [==============================] - 4s 179ms/step - loss: 0.2062 - tversky_loss: 2.1154 - dice_coef: 0.9216 - val_loss: 0.2540 - val_tversky_loss: 2.1260 - val_dice_coef: 0.9130
# Epoch 97/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2592 - tversky_loss: 2.1401 - dice_coef: 0.9038
# Epoch 00097: val_dice_coef did not improve from 0.93462
# 20/20 [==============================] - 4s 185ms/step - loss: 0.2603 - tversky_loss: 2.1399 - dice_coef: 0.9044 - val_loss: 0.2806 - val_tversky_loss: 2.1405 - val_dice_coef: 0.9077
# Epoch 98/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2483 - tversky_loss: 2.1358 - dice_coef: 0.9086
# Epoch 00098: val_dice_coef did not improve from 0.93462
# 20/20 [==============================] - 4s 185ms/step - loss: 0.2422 - tversky_loss: 2.1336 - dice_coef: 0.9099 - val_loss: 0.2466 - val_tversky_loss: 2.1260 - val_dice_coef: 0.9165
# Epoch 99/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2425 - tversky_loss: 2.1367 - dice_coef: 0.9061
# Epoch 00099: val_dice_coef improved from 0.93462 to 0.93597, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 201ms/step - loss: 0.2428 - tversky_loss: 2.1382 - dice_coef: 0.9051 - val_loss: 0.2201 - val_tversky_loss: 2.1005 - val_dice_coef: 0.9360
# Epoch 100/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2142 - tversky_loss: 2.1209 - dice_coef: 0.9174
# Epoch 00100: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 183ms/step - loss: 0.2152 - tversky_loss: 2.1208 - dice_coef: 0.9172 - val_loss: 0.2503 - val_tversky_loss: 2.1261 - val_dice_coef: 0.9129
# Epoch 101/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2244 - tversky_loss: 2.1295 - dice_coef: 0.9090
# Epoch 00101: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 183ms/step - loss: 0.2219 - tversky_loss: 2.1286 - dice_coef: 0.9098 - val_loss: 0.2113 - val_tversky_loss: 2.1114 - val_dice_coef: 0.9266
# Epoch 102/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2433 - tversky_loss: 2.1291 - dice_coef: 0.9125
# Epoch 00102: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 180ms/step - loss: 0.2320 - tversky_loss: 2.1230 - dice_coef: 0.9167 - val_loss: 0.2510 - val_tversky_loss: 2.1354 - val_dice_coef: 0.9105
# Epoch 103/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2287 - tversky_loss: 2.1268 - dice_coef: 0.9136
# Epoch 00103: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 182ms/step - loss: 0.2329 - tversky_loss: 2.1296 - dice_coef: 0.9112 - val_loss: 0.2334 - val_tversky_loss: 2.1309 - val_dice_coef: 0.9100
# Epoch 104/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2043 - tversky_loss: 2.1137 - dice_coef: 0.9218
# Epoch 00104: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 183ms/step - loss: 0.2096 - tversky_loss: 2.1170 - dice_coef: 0.9194 - val_loss: 0.2964 - val_tversky_loss: 2.1495 - val_dice_coef: 0.9017
# Epoch 105/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2451 - tversky_loss: 2.1349 - dice_coef: 0.9079
# Epoch 00105: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 185ms/step - loss: 0.2385 - tversky_loss: 2.1315 - dice_coef: 0.9106 - val_loss: 0.2380 - val_tversky_loss: 2.1354 - val_dice_coef: 0.9078
# Epoch 106/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2331 - tversky_loss: 2.1346 - dice_coef: 0.9066
# Epoch 00106: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 180ms/step - loss: 0.2326 - tversky_loss: 2.1336 - dice_coef: 0.9073 - val_loss: 0.3214 - val_tversky_loss: 2.1389 - val_dice_coef: 0.9105
# Epoch 107/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2408 - tversky_loss: 2.1335 - dice_coef: 0.9089
# Epoch 00107: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 187ms/step - loss: 0.2344 - tversky_loss: 2.1300 - dice_coef: 0.9116 - val_loss: 0.2226 - val_tversky_loss: 2.1119 - val_dice_coef: 0.9233
# Epoch 108/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2266 - tversky_loss: 2.1224 - dice_coef: 0.9178
# Epoch 00108: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 184ms/step - loss: 0.2250 - tversky_loss: 2.1223 - dice_coef: 0.9180 - val_loss: 0.2941 - val_tversky_loss: 2.1494 - val_dice_coef: 0.8984
# Epoch 109/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2324 - tversky_loss: 2.1343 - dice_coef: 0.9063
# Epoch 00109: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 183ms/step - loss: 0.2353 - tversky_loss: 2.1351 - dice_coef: 0.9054 - val_loss: 0.2079 - val_tversky_loss: 2.1091 - val_dice_coef: 0.9300
# Epoch 110/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2354 - tversky_loss: 2.1338 - dice_coef: 0.9085
# Epoch 00110: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 184ms/step - loss: 0.2310 - tversky_loss: 2.1307 - dice_coef: 0.9104 - val_loss: 0.2164 - val_tversky_loss: 2.1265 - val_dice_coef: 0.9085
# Epoch 111/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2322 - tversky_loss: 2.1276 - dice_coef: 0.9130
# Epoch 00111: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 183ms/step - loss: 0.2266 - tversky_loss: 2.1245 - dice_coef: 0.9154 - val_loss: 0.2527 - val_tversky_loss: 2.1228 - val_dice_coef: 0.9176
# Epoch 112/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2076 - tversky_loss: 2.1161 - dice_coef: 0.9204
# Epoch 00112: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 185ms/step - loss: 0.2050 - tversky_loss: 2.1156 - dice_coef: 0.9204 - val_loss: 0.2718 - val_tversky_loss: 2.1389 - val_dice_coef: 0.9121
# Epoch 113/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1997 - tversky_loss: 2.1197 - dice_coef: 0.9161
# Epoch 00113: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 184ms/step - loss: 0.2072 - tversky_loss: 2.1227 - dice_coef: 0.9145 - val_loss: 0.2877 - val_tversky_loss: 2.1353 - val_dice_coef: 0.9082
# Epoch 114/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2121 - tversky_loss: 2.1156 - dice_coef: 0.9207
# Epoch 00114: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 184ms/step - loss: 0.2111 - tversky_loss: 2.1144 - dice_coef: 0.9216 - val_loss: 0.3002 - val_tversky_loss: 2.1488 - val_dice_coef: 0.9057
# Epoch 115/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2342 - tversky_loss: 2.1310 - dice_coef: 0.9089
# Epoch 00115: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 188ms/step - loss: 0.2368 - tversky_loss: 2.1330 - dice_coef: 0.9073 - val_loss: 0.2239 - val_tversky_loss: 2.1217 - val_dice_coef: 0.9219
# Epoch 116/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2312 - tversky_loss: 2.1211 - dice_coef: 0.9188
# Epoch 00116: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 179ms/step - loss: 0.2295 - tversky_loss: 2.1211 - dice_coef: 0.9182 - val_loss: 0.2337 - val_tversky_loss: 2.1112 - val_dice_coef: 0.9239
# Epoch 117/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2363 - tversky_loss: 2.1278 - dice_coef: 0.9145
# Epoch 00117: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 185ms/step - loss: 0.2316 - tversky_loss: 2.1267 - dice_coef: 0.9149 - val_loss: 0.2822 - val_tversky_loss: 2.1435 - val_dice_coef: 0.9021
# Epoch 118/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2624 - tversky_loss: 2.1399 - dice_coef: 0.9038
# Epoch 00118: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 188ms/step - loss: 0.2620 - tversky_loss: 2.1389 - dice_coef: 0.9051 - val_loss: 0.2282 - val_tversky_loss: 2.1199 - val_dice_coef: 0.9208
# Epoch 119/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2301 - tversky_loss: 2.1289 - dice_coef: 0.9128
# Epoch 00119: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 183ms/step - loss: 0.2247 - tversky_loss: 2.1260 - dice_coef: 0.9145 - val_loss: 0.2077 - val_tversky_loss: 2.1168 - val_dice_coef: 0.9201
# Epoch 120/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2333 - tversky_loss: 2.1277 - dice_coef: 0.9118
# Epoch 00120: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 185ms/step - loss: 0.2347 - tversky_loss: 2.1288 - dice_coef: 0.9109 - val_loss: 0.2554 - val_tversky_loss: 2.1313 - val_dice_coef: 0.9103
# Epoch 121/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2163 - tversky_loss: 2.1270 - dice_coef: 0.9103
# Epoch 00121: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 185ms/step - loss: 0.2177 - tversky_loss: 2.1288 - dice_coef: 0.9086 - val_loss: 0.2763 - val_tversky_loss: 2.1391 - val_dice_coef: 0.9040
# Epoch 122/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2164 - tversky_loss: 2.1169 - dice_coef: 0.9192
# Epoch 00122: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 183ms/step - loss: 0.2144 - tversky_loss: 2.1172 - dice_coef: 0.9192 - val_loss: 0.2210 - val_tversky_loss: 2.1220 - val_dice_coef: 0.9115
# Epoch 123/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2332 - tversky_loss: 2.1220 - dice_coef: 0.9170
# Epoch 00123: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 177ms/step - loss: 0.2349 - tversky_loss: 2.1232 - dice_coef: 0.9157 - val_loss: 0.2468 - val_tversky_loss: 2.1075 - val_dice_coef: 0.9240
# Epoch 124/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2265 - tversky_loss: 2.1250 - dice_coef: 0.9132
# Epoch 00124: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 184ms/step - loss: 0.2246 - tversky_loss: 2.1242 - dice_coef: 0.9138 - val_loss: 0.2403 - val_tversky_loss: 2.1175 - val_dice_coef: 0.9205
# Epoch 125/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2045 - tversky_loss: 2.1202 - dice_coef: 0.9140
# Epoch 00125: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 184ms/step - loss: 0.2054 - tversky_loss: 2.1201 - dice_coef: 0.9139 - val_loss: 0.2077 - val_tversky_loss: 2.0990 - val_dice_coef: 0.9296
# Epoch 126/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2116 - tversky_loss: 2.1159 - dice_coef: 0.9184
# Epoch 00126: val_dice_coef did not improve from 0.93597
# 20/20 [==============================] - 4s 184ms/step - loss: 0.2160 - tversky_loss: 2.1171 - dice_coef: 0.9183 - val_loss: 0.2973 - val_tversky_loss: 2.1442 - val_dice_coef: 0.9012
# Epoch 127/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2132 - tversky_loss: 2.1193 - dice_coef: 0.9173
# Epoch 00127: val_dice_coef improved from 0.93597 to 0.93914, saving model to weedmap_model_vgg16_driunet_checkpoint_1.h5
# 20/20 [==============================] - 4s 206ms/step - loss: 0.2119 - tversky_loss: 2.1183 - dice_coef: 0.9181 - val_loss: 0.1421 - val_tversky_loss: 2.0787 - val_dice_coef: 0.9391
# Epoch 128/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2134 - tversky_loss: 2.1218 - dice_coef: 0.9123
# Epoch 00128: val_dice_coef did not improve from 0.93914
# 20/20 [==============================] - 4s 183ms/step - loss: 0.2106 - tversky_loss: 2.1212 - dice_coef: 0.9125 - val_loss: 0.2479 - val_tversky_loss: 2.1172 - val_dice_coef: 0.9157
# Epoch 129/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.2127 - tversky_loss: 2.1140 - dice_coef: 0.9194
# Epoch 00129: val_dice_coef did not improve from 0.93914
# 20/20 [==============================] - 4s 182ms/step - loss: 0.2117 - tversky_loss: 2.1138 - dice_coef: 0.9200 - val_loss: 0.1835 - val_tversky_loss: 2.0955 - val_dice_coef: 0.9320
# Epoch 130/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1950 - tversky_loss: 2.1118 - dice_coef: 0.9205
# Epoch 00130: val_dice_coef did not improve from 0.93914
# 20/20 [==============================] - 4s 180ms/step - loss: 0.1903 - tversky_loss: 2.1094 - dice_coef: 0.9220 - val_loss: 0.2411 - val_tversky_loss: 2.1176 - val_dice_coef: 0.9191
# Epoch 131/300
# ...
# Epoch 257/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1441 - tversky_loss: 2.0867 - dice_coef: 0.9326
# Epoch 00257: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 179ms/step - loss: 0.1414 - tversky_loss: 2.0857 - dice_coef: 0.9333 - val_loss: 0.1346 - val_tversky_loss: 2.0727 - val_dice_coef: 0.9397
# Epoch 258/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1366 - tversky_loss: 2.0850 - dice_coef: 0.9328
# Epoch 00258: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 182ms/step - loss: 0.1340 - tversky_loss: 2.0832 - dice_coef: 0.9342 - val_loss: 0.1453 - val_tversky_loss: 2.0806 - val_dice_coef: 0.9390
# Epoch 259/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1319 - tversky_loss: 2.0831 - dice_coef: 0.9351
# Epoch 00259: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 179ms/step - loss: 0.1375 - tversky_loss: 2.0853 - dice_coef: 0.9332 - val_loss: 0.1355 - val_tversky_loss: 2.0818 - val_dice_coef: 0.9348
# Epoch 260/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1258 - tversky_loss: 2.0826 - dice_coef: 0.9351
# Epoch 00260: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 179ms/step - loss: 0.1276 - tversky_loss: 2.0837 - dice_coef: 0.9343 - val_loss: 0.1487 - val_tversky_loss: 2.0683 - val_dice_coef: 0.9466
# Epoch 261/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1328 - tversky_loss: 2.0882 - dice_coef: 0.9301
# Epoch 00261: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 179ms/step - loss: 0.1341 - tversky_loss: 2.0895 - dice_coef: 0.9290 - val_loss: 0.1592 - val_tversky_loss: 2.0737 - val_dice_coef: 0.9437
# Epoch 262/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1363 - tversky_loss: 2.0834 - dice_coef: 0.9353
# Epoch 00262: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 176ms/step - loss: 0.1374 - tversky_loss: 2.0848 - dice_coef: 0.9340 - val_loss: 0.1993 - val_tversky_loss: 2.0860 - val_dice_coef: 0.9298
# Epoch 263/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1394 - tversky_loss: 2.0883 - dice_coef: 0.9299
# Epoch 00263: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 180ms/step - loss: 0.1381 - tversky_loss: 2.0882 - dice_coef: 0.9300 - val_loss: 0.1441 - val_tversky_loss: 2.0839 - val_dice_coef: 0.9302
# Epoch 264/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1438 - tversky_loss: 2.0878 - dice_coef: 0.9313
# Epoch 00264: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 181ms/step - loss: 0.1405 - tversky_loss: 2.0870 - dice_coef: 0.9317 - val_loss: 0.2202 - val_tversky_loss: 2.1024 - val_dice_coef: 0.9203
# Epoch 265/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1126 - tversky_loss: 2.0744 - dice_coef: 0.9407
# Epoch 00265: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 182ms/step - loss: 0.1097 - tversky_loss: 2.0729 - dice_coef: 0.9420 - val_loss: 0.1441 - val_tversky_loss: 2.0817 - val_dice_coef: 0.9355
# Epoch 266/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1256 - tversky_loss: 2.0789 - dice_coef: 0.9386
# Epoch 00266: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 179ms/step - loss: 0.1279 - tversky_loss: 2.0823 - dice_coef: 0.9354 - val_loss: 0.2314 - val_tversky_loss: 2.1012 - val_dice_coef: 0.9176
# Epoch 267/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1269 - tversky_loss: 2.0842 - dice_coef: 0.9320
# Epoch 00267: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 180ms/step - loss: 0.1268 - tversky_loss: 2.0842 - dice_coef: 0.9323 - val_loss: 0.1301 - val_tversky_loss: 2.0719 - val_dice_coef: 0.9413
# Epoch 268/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1380 - tversky_loss: 2.0868 - dice_coef: 0.9310
# Epoch 00268: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 183ms/step - loss: 0.1419 - tversky_loss: 2.0881 - dice_coef: 0.9303 - val_loss: 0.1796 - val_tversky_loss: 2.0905 - val_dice_coef: 0.9269
# Epoch 269/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1161 - tversky_loss: 2.0761 - dice_coef: 0.9396
# Epoch 00269: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 175ms/step - loss: 0.1148 - tversky_loss: 2.0750 - dice_coef: 0.9406 - val_loss: 0.1508 - val_tversky_loss: 2.0791 - val_dice_coef: 0.9374
# Epoch 270/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1132 - tversky_loss: 2.0761 - dice_coef: 0.9391
# Epoch 00270: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 180ms/step - loss: 0.1146 - tversky_loss: 2.0761 - dice_coef: 0.9392 - val_loss: 0.2066 - val_tversky_loss: 2.0955 - val_dice_coef: 0.9222
# Epoch 271/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1230 - tversky_loss: 2.0828 - dice_coef: 0.9341
# Epoch 00271: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 179ms/step - loss: 0.1240 - tversky_loss: 2.0836 - dice_coef: 0.9335 - val_loss: 0.1560 - val_tversky_loss: 2.0789 - val_dice_coef: 0.9356
# Epoch 272/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1298 - tversky_loss: 2.0874 - dice_coef: 0.9297
# Epoch 00272: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 176ms/step - loss: 0.1268 - tversky_loss: 2.0864 - dice_coef: 0.9303 - val_loss: 0.1487 - val_tversky_loss: 2.0797 - val_dice_coef: 0.9363
# Epoch 273/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1085 - tversky_loss: 2.0717 - dice_coef: 0.9432
# Epoch 00273: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 183ms/step - loss: 0.1152 - tversky_loss: 2.0744 - dice_coef: 0.9413 - val_loss: 0.0940 - val_tversky_loss: 2.0584 - val_dice_coef: 0.9538
# Epoch 274/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1380 - tversky_loss: 2.0893 - dice_coef: 0.9298
# Epoch 00274: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 182ms/step - loss: 0.1411 - tversky_loss: 2.0919 - dice_coef: 0.9274 - val_loss: 0.1462 - val_tversky_loss: 2.0734 - val_dice_coef: 0.9418
# Epoch 275/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1443 - tversky_loss: 2.0881 - dice_coef: 0.9308
# Epoch 00275: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 180ms/step - loss: 0.1417 - tversky_loss: 2.0869 - dice_coef: 0.9315 - val_loss: 0.1313 - val_tversky_loss: 2.0811 - val_dice_coef: 0.9331
# Epoch 276/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1278 - tversky_loss: 2.0806 - dice_coef: 0.9367
# Epoch 00276: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 177ms/step - loss: 0.1284 - tversky_loss: 2.0812 - dice_coef: 0.9360 - val_loss: 0.2139 - val_tversky_loss: 2.1074 - val_dice_coef: 0.9146
# Epoch 277/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1327 - tversky_loss: 2.0852 - dice_coef: 0.9328
# Epoch 00277: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 180ms/step - loss: 0.1348 - tversky_loss: 2.0864 - dice_coef: 0.9319 - val_loss: 0.1753 - val_tversky_loss: 2.0826 - val_dice_coef: 0.9360
# Epoch 278/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1205 - tversky_loss: 2.0790 - dice_coef: 0.9375
# Epoch 00278: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 182ms/step - loss: 0.1230 - tversky_loss: 2.0801 - dice_coef: 0.9367 - val_loss: 0.1463 - val_tversky_loss: 2.0761 - val_dice_coef: 0.9379
# Epoch 279/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1206 - tversky_loss: 2.0810 - dice_coef: 0.9355
# Epoch 00279: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 176ms/step - loss: 0.1249 - tversky_loss: 2.0828 - dice_coef: 0.9340 - val_loss: 0.1779 - val_tversky_loss: 2.0826 - val_dice_coef: 0.9352
# Epoch 280/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1430 - tversky_loss: 2.0874 - dice_coef: 0.9320
# Epoch 00280: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 182ms/step - loss: 0.1374 - tversky_loss: 2.0843 - dice_coef: 0.9343 - val_loss: 0.1703 - val_tversky_loss: 2.0877 - val_dice_coef: 0.9280
# Epoch 281/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1298 - tversky_loss: 2.0869 - dice_coef: 0.9310
# Epoch 00281: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 180ms/step - loss: 0.1322 - tversky_loss: 2.0873 - dice_coef: 0.9307 - val_loss: 0.1976 - val_tversky_loss: 2.0957 - val_dice_coef: 0.9224
# Epoch 282/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1337 - tversky_loss: 2.0834 - dice_coef: 0.9345
# Epoch 00282: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 180ms/step - loss: 0.1346 - tversky_loss: 2.0841 - dice_coef: 0.9341 - val_loss: 0.1298 - val_tversky_loss: 2.0696 - val_dice_coef: 0.9428
# Epoch 283/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1287 - tversky_loss: 2.0811 - dice_coef: 0.9358
# Epoch 00283: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 181ms/step - loss: 0.1336 - tversky_loss: 2.0834 - dice_coef: 0.9343 - val_loss: 0.1280 - val_tversky_loss: 2.0715 - val_dice_coef: 0.9423
# Epoch 284/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1464 - tversky_loss: 2.0909 - dice_coef: 0.9287
# Epoch 00284: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 183ms/step - loss: 0.1478 - tversky_loss: 2.0925 - dice_coef: 0.9274 - val_loss: 0.1937 - val_tversky_loss: 2.0924 - val_dice_coef: 0.9258
# Epoch 285/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1244 - tversky_loss: 2.0808 - dice_coef: 0.9365
# Epoch 00285: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 180ms/step - loss: 0.1229 - tversky_loss: 2.0796 - dice_coef: 0.9374 - val_loss: 0.1222 - val_tversky_loss: 2.0591 - val_dice_coef: 0.9508
# Epoch 286/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1157 - tversky_loss: 2.0756 - dice_coef: 0.9406
# Epoch 00286: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 175ms/step - loss: 0.1204 - tversky_loss: 2.0787 - dice_coef: 0.9379 - val_loss: 0.1839 - val_tversky_loss: 2.0870 - val_dice_coef: 0.9293
# Epoch 287/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1275 - tversky_loss: 2.0763 - dice_coef: 0.9411
# Epoch 00287: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 179ms/step - loss: 0.1280 - tversky_loss: 2.0773 - dice_coef: 0.9402 - val_loss: 0.2008 - val_tversky_loss: 2.0920 - val_dice_coef: 0.9268
# Epoch 288/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1399 - tversky_loss: 2.0868 - dice_coef: 0.9316
# Epoch 00288: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 179ms/step - loss: 0.1417 - tversky_loss: 2.0875 - dice_coef: 0.9313 - val_loss: 0.1618 - val_tversky_loss: 2.0738 - val_dice_coef: 0.9401
# Epoch 289/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1419 - tversky_loss: 2.0905 - dice_coef: 0.9287
# Epoch 00289: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 177ms/step - loss: 0.1519 - tversky_loss: 2.0934 - dice_coef: 0.9262 - val_loss: 0.1466 - val_tversky_loss: 2.0640 - val_dice_coef: 0.9476
# Epoch 290/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1476 - tversky_loss: 2.0896 - dice_coef: 0.9308
# Epoch 00290: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 178ms/step - loss: 0.1498 - tversky_loss: 2.0914 - dice_coef: 0.9292 - val_loss: 0.1652 - val_tversky_loss: 2.0849 - val_dice_coef: 0.9325
# Epoch 291/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1370 - tversky_loss: 2.0835 - dice_coef: 0.9357
# Epoch 00291: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 179ms/step - loss: 0.1344 - tversky_loss: 2.0820 - dice_coef: 0.9369 - val_loss: 0.1150 - val_tversky_loss: 2.0673 - val_dice_coef: 0.9471
# Epoch 292/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1109 - tversky_loss: 2.0774 - dice_coef: 0.9375
# Epoch 00292: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 178ms/step - loss: 0.1144 - tversky_loss: 2.0794 - dice_coef: 0.9360 - val_loss: 0.1472 - val_tversky_loss: 2.0752 - val_dice_coef: 0.9370
# Epoch 293/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1163 - tversky_loss: 2.0751 - dice_coef: 0.9413
# Epoch 00293: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 178ms/step - loss: 0.1196 - tversky_loss: 2.0761 - dice_coef: 0.9403 - val_loss: 0.1828 - val_tversky_loss: 2.0836 - val_dice_coef: 0.9291
# Epoch 294/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1372 - tversky_loss: 2.0899 - dice_coef: 0.9286
# Epoch 00294: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 181ms/step - loss: 0.1367 - tversky_loss: 2.0890 - dice_coef: 0.9295 - val_loss: 0.1455 - val_tversky_loss: 2.0847 - val_dice_coef: 0.9306
# Epoch 295/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1475 - tversky_loss: 2.0945 - dice_coef: 0.9254
# Epoch 00295: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 182ms/step - loss: 0.1468 - tversky_loss: 2.0947 - dice_coef: 0.9252 - val_loss: 0.1754 - val_tversky_loss: 2.0922 - val_dice_coef: 0.9280
# Epoch 296/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1124 - tversky_loss: 2.0772 - dice_coef: 0.9374
# Epoch 00296: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 178ms/step - loss: 0.1142 - tversky_loss: 2.0780 - dice_coef: 0.9365 - val_loss: 0.1229 - val_tversky_loss: 2.0686 - val_dice_coef: 0.9426
# Epoch 297/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1237 - tversky_loss: 2.0786 - dice_coef: 0.9378
# Epoch 00297: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 182ms/step - loss: 0.1277 - tversky_loss: 2.0805 - dice_coef: 0.9364 - val_loss: 0.1940 - val_tversky_loss: 2.0868 - val_dice_coef: 0.9317
# Epoch 298/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1346 - tversky_loss: 2.0845 - dice_coef: 0.9341
# Epoch 00298: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 183ms/step - loss: 0.1320 - tversky_loss: 2.0837 - dice_coef: 0.9347 - val_loss: 0.1256 - val_tversky_loss: 2.0700 - val_dice_coef: 0.9417
# Epoch 299/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1241 - tversky_loss: 2.0833 - dice_coef: 0.9332
# Epoch 00299: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 183ms/step - loss: 0.1244 - tversky_loss: 2.0838 - dice_coef: 0.9328 - val_loss: 0.1968 - val_tversky_loss: 2.0929 - val_dice_coef: 0.9268
# Epoch 300/300
# 19/20 [===========================>..] - ETA: 0s - loss: 0.1205 - tversky_loss: 2.0778 - dice_coef: 0.9387
# Epoch 00300: val_dice_coef did not improve from 0.95584
# 20/20 [==============================] - 4s 179ms/step - loss: 0.1176 - tversky_loss: 2.0755 - dice_coef: 0.9406 - val_loss: 0.1944 - val_tversky_loss: 2.0939 - val_dice_coef: 0.9264

# %%
DriuNet_test = driunet_functional(3, input_height=224, input_width=224, input_depth=3)
DriuNet_test.load_weights('weedmap_model_vgg16_driunet_checkpoint_1.h5')

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ### Model evaluation historical plots

# %%
# Get actual number of epochs model was trained for
N = len(result.history['loss'])

#Plot the model evaluation history
plt.style.use("ggplot")
fig = plt.figure(figsize=(20,8))

fig.add_subplot(1,2,1)
plt.title("Training Loss")
plt.plot(np.arange(0, N), result.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), result.history["val_loss"], label="val_loss")
#plt.ylim(0, 1)

fig.add_subplot(1,2,2)
plt.title("Training Dice Coef")
plt.plot(np.arange(0, N), result.history["dice_coef"], label="train_dice_coef")
plt.plot(np.arange(0, N), result.history["val_dice_coef"], label="val_dice_coef")
#plt.ylim(0, 1)

plt.xlabel("Epoch #")
plt.ylabel("Loss/Dice Coef")
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# ### Extract and display model frame, prediction and mask

# %%
#Create iterators for frames and masks
X_TEST = []
Y_TEST = []
test_frame_batches = tf.compat.v1.data.make_one_shot_iterator(test_frame_tensors)  # outside of TF Eager, we would use make_one_shot_iterator
test_mask_batches = tf.compat.v1.data.make_one_shot_iterator(test_masks_tensors)

    
#Iterate over the train images while saving the frames and masks in appropriate folders
dir_name='test'
i=0
for file in zip(test_frames_list, test_masks_list):
    #Convert tensors to numpy arrays
    frame = test_frame_batches.next().numpy().astype(np.uint8)
    mask = test_mask_batches.next().numpy().astype(np.uint8)
    if mask.shape != (224, 224, 1):
            #Convert numpy arrays to images
        X_TEST.append(frame / 255.)
        Y_TEST.append(mask)
        if i%20 == 0:
            print("[INFO] Iteration num: {}".format(i))
        i +=1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in make_one_shot_iterator(dataset)
#    2069     # datasets (e.g. for prefetching) override its behavior.
# -> 2070     return dataset._make_one_shot_iterator()  # pylint: disable=protected-access
#    2071   except AttributeError:
#
# AttributeError: 'IteratorV2' object has no attribute '_make_one_shot_iterator'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in __init__(self)
#    1612     try:
# -> 1613       variant_tensor = self._as_variant_tensor()
#    1614     except AttributeError as e:
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in _as_variant_tensor(self)
#    2005   def _as_variant_tensor(self):
# -> 2006     return self._dataset._variant_tensor  # pylint: disable=protected-access
#    2007
#
# AttributeError: 'IteratorV2' object has no attribute '_variant_tensor'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-ce937b148b37> in <module>
#       3 Y_TEST = []
#       4 test_frame_batches = tf.compat.v1.data.make_one_shot_iterator(test_frame_tensors)  # outside of TF Eager, we would use make_one_shot_iterator
# ----> 5 test_mask_batches = tf.compat.v1.data.make_one_shot_iterator(test_masks_tensors)
#       6
#       7
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in make_one_shot_iterator(dataset)
#    2070     return dataset._make_one_shot_iterator()  # pylint: disable=protected-access
#    2071   except AttributeError:
# -> 2072     return DatasetV1Adapter(dataset)._make_one_shot_iterator()  # pylint: disable=protected-access
#    2073
#    2074
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in __init__(self, dataset)
#    2001   def __init__(self, dataset):
#    2002     self._dataset = dataset
# -> 2003     super(DatasetV1Adapter, self).__init__()
#    2004
#    2005   def _as_variant_tensor(self):
#
# ~/venv/lib/python3.6/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in __init__(self)
#    1623                            "if that uses attributes defined in the __init__ "
#    1624                            "method, those attrs need to be defined before the "
# -> 1625                            "super call.".format(e))
#    1626     super(DatasetV1, self).__init__(variant_tensor)
#    1627
#
# AttributeError: 'IteratorV2' object has no attribute '_variant_tensor': A likely cause of this error is that the super call for this dataset is not the last line of the __init__ method. The base class causes the _as_variant_tensor call in its constructor and if that uses attributes defined in the __init__ method, those attrs need to be defined before the super call.

# %%
X_TEST = np.asarray(X_TEST)
Y_TEST = np.array(Y_TEST)
Y_TEST_PRED = model_test.predict(X_TEST)
print("Test images shape: {}".format(X_TEST.shape))
print("Test masks shape: {}".format(Y_TEST.shape))
print("Test masks predict shape: {}".format(Y_TEST_PRED.shape))
# Out:
# Test images shape: (93, 224, 224, 3)
# Test masks shape: (93, 224, 224, 3)
# Test masks predict shape: (93, 224, 224, 3)

# %%
#Plot the the mask test image
plt.style.use("ggplot")
fig = plt.figure(figsize=(20,8))
plt.imshow(Y_TEST[1])

# %% [markdown]
# ### Binaryze the masks and calculate the AUC score

# %%
# ground truth color masks
image_num = 1
Y_TEST_WEED = []
Y_TEST_CROP = []
Y_TEST_BG = []
Y_TEST_PRED_WEED = []
Y_TEST_PRED_CROP = []
Y_TEST_BG = []

def rgb_to_binary_masks(mask):
    ## mask of green (36,25,25) ~ (86, 255,255)
    # mask = cv2.inRange(hsv, (36, 25, 25), (86, 255,255))
    _, WEED = cv2.threshold(mask[:, :, 0], 50, 255, cv2.THRESH_BINARY)
    _, CROP = cv2.threshold(mask[:, :, 1], 50, 255, cv2.THRESH_BINARY)
    BG = cv2.inRange(mask, (0, 0, 0), (50, 50, 50), cv2.THRESH_BINARY)
    
    return WEED, CROP, BG

gt_weed, gt_crop, gt_bg = rgb_to_binary_masks(Y_TEST[image_num])
pred_weed, pred_crop, pred_bg = rgb_to_binary_masks(onehot_to_rgb((Y_TEST_PRED[image_num])))


plt.figure(figsize=[15,8])
plt.subplot(241);plt.imshow(Y_TEST[image_num]);plt.title('Original Mask');
plt.subplot(242);plt.imshow(gt_weed, cmap='gray');plt.title('GT Weed Binary Mask');
plt.subplot(243);plt.imshow(gt_crop,cmap='gray');plt.title('GT Crop Binary Mask');
plt.subplot(244);plt.imshow(gt_bg,cmap='gray');plt.title('GT BG Binary Image');
plt.subplot(245);plt.imshow(onehot_to_rgb(Y_TEST_PRED[image_num]));plt.title('Predicted Mask');
plt.subplot(246);plt.imshow(pred_weed,cmap='gray');plt.title('Pred Weed Mask Image');
plt.subplot(247);plt.imshow(pred_crop,cmap='gray');plt.title('Pred Crop Binary Mask');
plt.subplot(248);plt.imshow(pred_bg,cmap='gray');plt.title('Pred BG Binary Image');

# %%
auc_crop_list = []
auc_weed_list = []
auc_bg_list = []
num_images = X_TEST.shape[0]
for image_num in range(num_images):
    gt_weed, gt_crop, gt_bg = rgb_to_binary_masks(Y_TEST[image_num])
    pred_weed, pred_crop, pred_bg = rgb_to_binary_masks(onehot_to_rgb((Y_TEST_PRED[image_num])))

    gt_weed_flat = gt_weed.flatten() / 255.
    gt_crop_flat = gt_crop.flatten()  / 255.
    gt_bg_flat = gt_bg.flatten() / 255.

    pred_weed_flat = pred_weed.flatten() / 255.
    pred_crop_flat = pred_crop.flatten()  / 255.
    pred_bg_flat = pred_bg.flatten() / 255.

    def roc_auc_score_FIXED(y_true, y_pred):
        if len(np.unique(y_true)) == 1: # bug in roc_auc_score
            return accuracy_score(y_true, np.rint(y_pred))
        return roc_auc_score(y_true, y_pred)
    # calculate scores
    #ns_auc = roc_auc_score(gt_weed_flat, ns_probs)
    weed_auc = roc_auc_score_FIXED(gt_weed_flat, pred_weed_flat)
    crop_auc = roc_auc_score_FIXED(gt_crop_flat, pred_crop_flat)
    bg_auc = roc_auc_score_FIXED(gt_bg_flat, pred_bg_flat)
    
    auc_crop_list.append(crop_auc)
    auc_weed_list.append(weed_auc)
    auc_bg_list.append(bg_auc)
# summarize scores

print('SegNet: Weed AUC={0:.3f}'.format(np.sum(auc_weed_list)/num_images))
print('SegNet: Crop AUC={0:.3f}'.format(np.sum(auc_crop_list)/num_images))
print('SegNet: BG AUC={0:.3f}'.format(np.sum(auc_bg_list)/num_images))
# Out:
# SegNet: Weed AUC=0.564
# SegNet: Crop AUC=0.776
# SegNet: BG AUC=0.674

# %% [markdown]
# | Author | AUC Weed| AUC Crop| AUC Bg|
# | --- | --- |--- |--- |
# | Sa, I. et. al (3CH RGB) | **0.576** |0.681 |0.607|
# | Our Method (3CH RGB) | 0.564 |**0.776** |**0.674**|
